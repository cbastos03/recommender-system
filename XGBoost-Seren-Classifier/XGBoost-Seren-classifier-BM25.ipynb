# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from sklearn.metrics import precision_score, recall_score, accuracy_score, mean_squared_error, mean_absolute_error
import optuna
import xgboost as xgb
import numpy as np

train_data = pd.read_csv('../train_data.csv', dtype={'item_id': str}, sep=';')
test_data = pd.read_csv('../test_data.csv', dtype={'item_id': str}, sep=';')
data = pd.read_csv('../Data/serenlens_with_features_cleaned_filtered.csv', dtype={'item_id': str}, sep=";")
all_item_ids = data['item_id'].unique()

# load serendipity classifier model
predict_serendipity = xgb.XGBClassifier()
predict_serendipity.load_model('../serendipity_classifier/serendipity_classifier_BM25.json')

def load_embeddings(embedding_path, item_ids):
    embeddings = np.load(embedding_path)
    return {item_id: normalize(embedding.reshape(1, -1)).flatten() for item_id, embedding in zip(item_ids, embeddings)}

train_user_ids = train_data['user_id'].unique()
train_item_ids = train_data['item_id'].unique()
train_user_id_map = {user_id: idx for idx, user_id in enumerate(train_user_ids)}
train_item_id_map = {item_id: idx for idx, item_id in enumerate(train_item_ids)}

interaction_matrix = train_data.pivot(index='user_id', columns='item_id', values='rating').fillna(0)
svd = TruncatedSVD(n_components=50, random_state=42)
user_embeddings = svd.fit_transform(interaction_matrix)
item_embeddings_mf = svd.components_.T

scaler = StandardScaler()
user_embeddings = scaler.fit_transform(user_embeddings)
item_embeddings_mf = scaler.fit_transform(item_embeddings_mf)

# description embeddings
item_embeddings_dict = load_embeddings('../embeddings/bm25_embeddings.npy', all_item_ids)

# default embedding for missing embeddings in test
default_user_embedding = np.mean(user_embeddings, axis=0)
default_item_embedding_svd = np.mean(item_embeddings_mf, axis=0)

default_user_embedding = normalize(default_user_embedding.reshape(1, -1)).flatten()
default_item_embedding_svd = normalize(default_item_embedding_svd.reshape(1, -1)).flatten()

def generate_embeddings(data, data_samples):
    combined_embedding = []
    for idx, row in data.iterrows():
        user_idx = train_user_id_map.get(row['user_id'])
        item_idx = train_item_id_map.get(row['item_id'])
        user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
        item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
        item_embedding_bert = item_embeddings_dict[row['item_id']]
        item_final = np.hstack((item_embedding_bert, item_embedding))
    
        #calculate serendipity using the serendipity classifier
        serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
        serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
        
        # favour serenpity interactions
        serendipity_weight = 1 + serendipit_pred
        item_final = item_final * serendipity_weight
    
        # add serendipity as a feature
        serendipity_feature = np.array([serendipit_pred]).reshape(1, -1).flatten()
        
        combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
        data_samples.append((combined_embedding, row['rating']))

train_data_samples = []
generate_embeddings(train_data, train_data_samples)
X_train, y_train = zip(*train_data_samples)
X_train = np.array(X_train)
y_train = np.array(y_train)

test_data_samples = []
generate_embeddings(test_data, test_data_samples)

X_test, y_test = zip(*test_data_samples)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

def objective(trial):
    param = {
        'objective': 'reg:squarederror',
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
    }
    
    xgb_model = xgb.XGBRegressor(**param)
    
    X_train_opt, X_valid_opt, y_train_opt, y_valid_opt = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    
    xgb_model.fit(X_train_opt, y_train_opt, eval_set=[(X_valid_opt, y_valid_opt)], verbose=False)
    
    y_pred = xgb_model.predict(X_valid_opt)
    
    mse = mean_squared_error(y_valid_opt, y_pred)
    
    # minimize mse    
    return mse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print("best hyperparameters found:")
print(study.best_params)

# use best hyperparameters
best_params = study.best_params
xgb_model = xgb.XGBRegressor(**best_params)
xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=True)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'test MSE: {mse}')
print(f'test MAE: {mae}')
# Out:
# [I 2024-09-21 16:09:25,961] A new study created in memory with name: no-name-8a6be153-56c2-4d1c-a26d-36d69476ce4b
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:11:13,634] Trial 0 finished with value: 0.7879888415336609 and parameters: {'n_estimators': 435, 'max_depth': 3, 'learning_rate': 0.040494227916409865, 'subsample': 0.8481850457269747, 'colsample_bytree': 0.9604502258699953, 'reg_alpha': 0.48882125065742515, 'reg_lambda': 0.12825873431698737}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:18:43,076] Trial 1 finished with value: 0.7916531562805176 and parameters: {'n_estimators': 405, 'max_depth': 8, 'learning_rate': 0.017902040512352363, 'subsample': 0.6522574771186657, 'colsample_bytree': 0.9426942712237782, 'reg_alpha': 0.4324471478559468, 'reg_lambda': 6.484904707823441}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:25:13,441] Trial 2 finished with value: 0.8029698729515076 and parameters: {'n_estimators': 205, 'max_depth': 10, 'learning_rate': 0.05909828452929171, 'subsample': 0.6832742125064185, 'colsample_bytree': 0.6667765480125194, 'reg_alpha': 1.3881798059229358, 'reg_lambda': 0.2687987207475932}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:27:42,510] Trial 3 finished with value: 0.8642877340316772 and parameters: {'n_estimators': 496, 'max_depth': 4, 'learning_rate': 0.18457471353045604, 'subsample': 0.9690888346664034, 'colsample_bytree': 0.784871245244803, 'reg_alpha': 1.198151254245925, 'reg_lambda': 1.2465802374040125}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:30:24,321] Trial 4 finished with value: 0.8296989798545837 and parameters: {'n_estimators': 389, 'max_depth': 5, 'learning_rate': 0.06429233662388081, 'subsample': 0.6701072652110438, 'colsample_bytree': 0.8239518055007458, 'reg_alpha': 2.9343302729357035, 'reg_lambda': 0.13575979471101637}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:31:22,215] Trial 5 finished with value: 0.7939738035202026 and parameters: {'n_estimators': 237, 'max_depth': 4, 'learning_rate': 0.06846340148100769, 'subsample': 0.7316845847467984, 'colsample_bytree': 0.9065616149143172, 'reg_alpha': 0.1902999124285764, 'reg_lambda': 2.2895263852081205}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:40:59,365] Trial 6 finished with value: 0.809090793132782 and parameters: {'n_estimators': 427, 'max_depth': 9, 'learning_rate': 0.06888706876806404, 'subsample': 0.9322374519005014, 'colsample_bytree': 0.7883641359054006, 'reg_alpha': 0.29478164032527004, 'reg_lambda': 1.057391503367083}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:45:06,851] Trial 7 finished with value: 0.8933537602424622 and parameters: {'n_estimators': 430, 'max_depth': 8, 'learning_rate': 0.25015430791677185, 'subsample': 0.9525267237780926, 'colsample_bytree': 0.7913286491020178, 'reg_alpha': 2.4167530087933455, 'reg_lambda': 1.9880682501835993}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:48:00,478] Trial 8 finished with value: 0.7895618081092834 and parameters: {'n_estimators': 298, 'max_depth': 6, 'learning_rate': 0.021535346202092714, 'subsample': 0.7723008545021705, 'colsample_bytree': 0.998310738154531, 'reg_alpha': 9.28420744046899, 'reg_lambda': 0.26407763831208236}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:51:25,928] Trial 9 finished with value: 0.9213374257087708 and parameters: {'n_estimators': 289, 'max_depth': 7, 'learning_rate': 0.2108517104977402, 'subsample': 0.6660217220326025, 'colsample_bytree': 0.6269986712812546, 'reg_alpha': 0.13770538888061948, 'reg_lambda': 3.203932718665105}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:53:07,783] Trial 10 finished with value: 0.7909346222877502 and parameters: {'n_estimators': 494, 'max_depth': 3, 'learning_rate': 0.01009389018029739, 'subsample': 0.8622617838120639, 'colsample_bytree': 0.8857326116975306, 'reg_alpha': 0.5540802029239451, 'reg_lambda': 0.10422786035127331}. Best is trial 0 with value: 0.7879888415336609.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:54:17,659] Trial 11 finished with value: 0.7836364507675171 and parameters: {'n_estimators': 111, 'max_depth': 6, 'learning_rate': 0.026880937357717207, 'subsample': 0.8056443869477392, 'colsample_bytree': 0.9924656359625779, 'reg_alpha': 6.006284480606581, 'reg_lambda': 0.35015445964742686}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:54:50,635] Trial 12 finished with value: 0.7904089093208313 and parameters: {'n_estimators': 129, 'max_depth': 3, 'learning_rate': 0.03652550426025789, 'subsample': 0.8619333800411215, 'colsample_bytree': 0.9968528558418687, 'reg_alpha': 8.572739056953605, 'reg_lambda': 0.35691814767009766}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:56:00,656] Trial 13 finished with value: 0.7862424254417419 and parameters: {'n_estimators': 119, 'max_depth': 6, 'learning_rate': 0.027741751156153713, 'subsample': 0.8417316272252784, 'colsample_bytree': 0.9480091690512695, 'reg_alpha': 3.343351193803254, 'reg_lambda': 0.38502984761750564}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:56:57,613] Trial 14 finished with value: 0.7879137396812439 and parameters: {'n_estimators': 104, 'max_depth': 6, 'learning_rate': 0.021127412312382812, 'subsample': 0.7824921919932671, 'colsample_bytree': 0.8555552029616841, 'reg_alpha': 3.8452377672687947, 'reg_lambda': 0.5343700622820016}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:58:43,121] Trial 15 finished with value: 0.8290733695030212 and parameters: {'n_estimators': 162, 'max_depth': 7, 'learning_rate': 0.11377769516960413, 'subsample': 0.8297727536865205, 'colsample_bytree': 0.7196810344952034, 'reg_alpha': 5.224915461084737, 'reg_lambda': 0.6311406896831672}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 16:59:39,896] Trial 16 finished with value: 0.7854381799697876 and parameters: {'n_estimators': 174, 'max_depth': 5, 'learning_rate': 0.03350651526891976, 'subsample': 0.9029209110191876, 'colsample_bytree': 0.9330415862160532, 'reg_alpha': 1.9738133893733225, 'reg_lambda': 0.5814117567696815}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:01:10,015] Trial 17 finished with value: 0.7901319265365601 and parameters: {'n_estimators': 211, 'max_depth': 5, 'learning_rate': 0.013948337554235687, 'subsample': 0.9109689176223261, 'colsample_bytree': 0.9105474167252632, 'reg_alpha': 1.8728942704278186, 'reg_lambda': 0.2079510250791938}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:02:27,490] Trial 18 finished with value: 0.7913458943367004 and parameters: {'n_estimators': 166, 'max_depth': 5, 'learning_rate': 0.0368311473460767, 'subsample': 0.6005051291639625, 'colsample_bytree': 0.8630596444856149, 'reg_alpha': 5.539803135216113, 'reg_lambda': 0.684810195801933}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:03:54,453] Trial 19 finished with value: 0.8024531602859497 and parameters: {'n_estimators': 254, 'max_depth': 4, 'learning_rate': 0.10020061608958401, 'subsample': 0.9074158009936841, 'colsample_bytree': 0.9560177506863643, 'reg_alpha': 0.8108088662441784, 'reg_lambda': 8.65882459620029}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:09:57,696] Trial 20 finished with value: 0.7931351661682129 and parameters: {'n_estimators': 355, 'max_depth': 8, 'learning_rate': 0.029278928267854974, 'subsample': 0.7390186329280463, 'colsample_bytree': 0.735187317397773, 'reg_alpha': 6.174105173513084, 'reg_lambda': 1.4078047243873715}. Best is trial 11 with value: 0.7836364507675171.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:11:23,885] Trial 21 finished with value: 0.779274582862854 and parameters: {'n_estimators': 143, 'max_depth': 6, 'learning_rate': 0.030152769480785966, 'subsample': 0.8929620904380066, 'colsample_bytree': 0.9230974043355782, 'reg_alpha': 3.2958601789543898, 'reg_lambda': 0.459393033653014}. Best is trial 21 with value: 0.779274582862854.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:12:32,884] Trial 22 finished with value: 0.7895684838294983 and parameters: {'n_estimators': 159, 'max_depth': 5, 'learning_rate': 0.04072402811942073, 'subsample': 0.9965274662151934, 'colsample_bytree': 0.9198137324311021, 'reg_alpha': 1.5237142079130868, 'reg_lambda': 0.8057667461809435}. Best is trial 21 with value: 0.779274582862854.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# ...
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:46:17,780] Trial 44 finished with value: 0.8060867786407471 and parameters: {'n_estimators': 225, 'max_depth': 3, 'learning_rate': 0.14983599426182734, 'subsample': 0.9288315534061703, 'colsample_bytree': 0.8689160210505645, 'reg_alpha': 4.661782471347033, 'reg_lambda': 0.3203480760429006}. Best is trial 21 with value: 0.779274582862854.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:46:51,879] Trial 45 finished with value: 0.7939081192016602 and parameters: {'n_estimators': 126, 'max_depth': 4, 'learning_rate': 0.07822189733459324, 'subsample': 0.8537543000136121, 'colsample_bytree': 0.8980523586478473, 'reg_alpha': 9.620232789732226, 'reg_lambda': 4.0743998741716405}. Best is trial 21 with value: 0.779274582862854.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:47:59,137] Trial 46 finished with value: 0.7879783511161804 and parameters: {'n_estimators': 148, 'max_depth': 6, 'learning_rate': 0.06133279406014286, 'subsample': 0.8765067406594768, 'colsample_bytree': 0.961576382461754, 'reg_alpha': 1.2045161730808334, 'reg_lambda': 0.7165558903665522}. Best is trial 21 with value: 0.779274582862854.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:49:48,452] Trial 47 finished with value: 0.795405924320221 and parameters: {'n_estimators': 260, 'max_depth': 6, 'learning_rate': 0.03769580888170864, 'subsample': 0.9629557228659236, 'colsample_bytree': 0.9347253130040281, 'reg_alpha': 0.663879327366333, 'reg_lambda': 0.5204104383244734}. Best is trial 21 with value: 0.779274582862854.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:52:15,659] Trial 48 finished with value: 0.7848385572433472 and parameters: {'n_estimators': 470, 'max_depth': 5, 'learning_rate': 0.012577838250573133, 'subsample': 0.7754244914474553, 'colsample_bytree': 0.6143886646836811, 'reg_alpha': 3.474925868402873, 'reg_lambda': 1.6993902977504476}. Best is trial 21 with value: 0.779274582862854.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:99: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:100: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:101: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_5520\2773908469.py:103: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 17:52:59,544] Trial 49 finished with value: 0.7845403552055359 and parameters: {'n_estimators': 121, 'max_depth': 5, 'learning_rate': 0.033100116598523535, 'subsample': 0.842051424862618, 'colsample_bytree': 0.9880756670634625, 'reg_alpha': 7.624421912089166, 'reg_lambda': 0.12442119232044704}. Best is trial 21 with value: 0.779274582862854.
# best hyperparameters found:
# {'n_estimators': 143, 'max_depth': 6, 'learning_rate': 0.030152769480785966, 'subsample': 0.8929620904380066, 'colsample_bytree': 0.9230974043355782, 'reg_alpha': 3.2958601789543898, 'reg_lambda': 0.459393033653014}
# [0]	validation_0-rmse:0.94640
# [1]	validation_0-rmse:0.94463
# [2]	validation_0-rmse:0.94276
# [3]	validation_0-rmse:0.94140
# [4]	validation_0-rmse:0.94005
# [5]	validation_0-rmse:0.93868
# [6]	validation_0-rmse:0.93761
# [7]	validation_0-rmse:0.93660
# [8]	validation_0-rmse:0.93540
# [9]	validation_0-rmse:0.93442
# [10]	validation_0-rmse:0.93357
# [11]	validation_0-rmse:0.93245
# [12]	validation_0-rmse:0.93066
# [13]	validation_0-rmse:0.92954
# [14]	validation_0-rmse:0.92815
# [15]	validation_0-rmse:0.92728
# [16]	validation_0-rmse:0.92648
# [17]	validation_0-rmse:0.92565
# [18]	validation_0-rmse:0.92461
# [19]	validation_0-rmse:0.92358
# [20]	validation_0-rmse:0.92239
# [21]	validation_0-rmse:0.92189
# [22]	validation_0-rmse:0.92133
# [23]	validation_0-rmse:0.92116
# [24]	validation_0-rmse:0.92060
# [25]	validation_0-rmse:0.91998
# [26]	validation_0-rmse:0.91951
# [27]	validation_0-rmse:0.91899
# [28]	validation_0-rmse:0.91835
# [29]	validation_0-rmse:0.91789
# [30]	validation_0-rmse:0.91736
# [31]	validation_0-rmse:0.91723
# [32]	validation_0-rmse:0.91702
# [33]	validation_0-rmse:0.91687
# [34]	validation_0-rmse:0.91640
# [35]	validation_0-rmse:0.91577
# [36]	validation_0-rmse:0.91570
# [37]	validation_0-rmse:0.91493
# [38]	validation_0-rmse:0.91478
# [39]	validation_0-rmse:0.91419
# [40]	validation_0-rmse:0.91390
# [41]	validation_0-rmse:0.91386
# [42]	validation_0-rmse:0.91355
# [43]	validation_0-rmse:0.91347
# [44]	validation_0-rmse:0.91325
# [45]	validation_0-rmse:0.91313
# [46]	validation_0-rmse:0.91311
# [47]	validation_0-rmse:0.91266
# [48]	validation_0-rmse:0.91238
# [49]	validation_0-rmse:0.91223
# [50]	validation_0-rmse:0.91178
# [51]	validation_0-rmse:0.91159
# [52]	validation_0-rmse:0.91170
# [53]	validation_0-rmse:0.91149
# [54]	validation_0-rmse:0.91146
# [55]	validation_0-rmse:0.91116
# [56]	validation_0-rmse:0.91122
# [57]	validation_0-rmse:0.91095
# [58]	validation_0-rmse:0.91077
# [59]	validation_0-rmse:0.91061
# [60]	validation_0-rmse:0.91068
# [61]	validation_0-rmse:0.91058
# [62]	validation_0-rmse:0.91053
# [63]	validation_0-rmse:0.91048
# [64]	validation_0-rmse:0.91057
# [65]	validation_0-rmse:0.91066
# [66]	validation_0-rmse:0.91056
# [67]	validation_0-rmse:0.91009
# [68]	validation_0-rmse:0.91002
# [69]	validation_0-rmse:0.90953
# [70]	validation_0-rmse:0.90950
# [71]	validation_0-rmse:0.90932
# [72]	validation_0-rmse:0.90941
# [73]	validation_0-rmse:0.90959
# [74]	validation_0-rmse:0.90950
# [75]	validation_0-rmse:0.90931
# [76]	validation_0-rmse:0.90923
# [77]	validation_0-rmse:0.90909
# [78]	validation_0-rmse:0.90902
# [79]	validation_0-rmse:0.90896
# [80]	validation_0-rmse:0.90898
# [81]	validation_0-rmse:0.90901
# [82]	validation_0-rmse:0.90898
# [83]	validation_0-rmse:0.90861
# [84]	validation_0-rmse:0.90854
# [85]	validation_0-rmse:0.90856
# [86]	validation_0-rmse:0.90837
# [87]	validation_0-rmse:0.90826
# [88]	validation_0-rmse:0.90794
# [89]	validation_0-rmse:0.90787
# [90]	validation_0-rmse:0.90746
# [91]	validation_0-rmse:0.90734
# [92]	validation_0-rmse:0.90755
# [93]	validation_0-rmse:0.90764
# [94]	validation_0-rmse:0.90758
# [95]	validation_0-rmse:0.90748
# [96]	validation_0-rmse:0.90754
# [97]	validation_0-rmse:0.90760
# [98]	validation_0-rmse:0.90748
# [99]	validation_0-rmse:0.90760
# [100]	validation_0-rmse:0.90741
# [101]	validation_0-rmse:0.90742
# [102]	validation_0-rmse:0.90731
# [103]	validation_0-rmse:0.90724
# [104]	validation_0-rmse:0.90733
# [105]	validation_0-rmse:0.90679
# [106]	validation_0-rmse:0.90669
# [107]	validation_0-rmse:0.90674
# [108]	validation_0-rmse:0.90684
# [109]	validation_0-rmse:0.90694
# [110]	validation_0-rmse:0.90688
# [111]	validation_0-rmse:0.90686
# [112]	validation_0-rmse:0.90691
# [113]	validation_0-rmse:0.90698
# [114]	validation_0-rmse:0.90692
# [115]	validation_0-rmse:0.90683
# [116]	validation_0-rmse:0.90670
# [117]	validation_0-rmse:0.90684
# [118]	validation_0-rmse:0.90669
# [119]	validation_0-rmse:0.90661
# [120]	validation_0-rmse:0.90682
# [121]	validation_0-rmse:0.90669
# [122]	validation_0-rmse:0.90660
# [123]	validation_0-rmse:0.90650
# [124]	validation_0-rmse:0.90641
# [125]	validation_0-rmse:0.90635
# [126]	validation_0-rmse:0.90641
# [127]	validation_0-rmse:0.90647
# [128]	validation_0-rmse:0.90657
# [129]	validation_0-rmse:0.90652
# [130]	validation_0-rmse:0.90647
# [131]	validation_0-rmse:0.90630
# [132]	validation_0-rmse:0.90649
# [133]	validation_0-rmse:0.90630
# [134]	validation_0-rmse:0.90623
# [135]	validation_0-rmse:0.90611
# [136]	validation_0-rmse:0.90601
# [137]	validation_0-rmse:0.90609
# [138]	validation_0-rmse:0.90575
# [139]	validation_0-rmse:0.90582
# [140]	validation_0-rmse:0.90575
# [141]	validation_0-rmse:0.90559
# [142]	validation_0-rmse:0.90547
# test MSE: 0.8198771476745605
# test MAE: 0.6970847249031067

# %%
import numpy as np
import random

def hit_rate_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    hits = len(set(predicted_at_k) & set(true_items))
    return 1.0 if hits > 0 else 0.0

def ndcg_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    dcg = 0.0
    idcg = sum((1.0 / np.log2(i + 2) for i in range(min(len(true_items), k))))
    
    for i, item in enumerate(predicted_at_k):
        if item in true_items:
            dcg += 1.0 / np.log2(i + 2)  # Log base 2

    return dcg / idcg if idcg > 0 else 0.0

hr_values = []
ndcg_values = []
hr_seren_values = []
ndcg_seren_values = []
rating_threshold = 3
serendipity_items = 0
serendipity_survival_items = 0
all_item_ids = set(all_item_ids)
number_negative_examples = 20
for k in [5,10]:
    for user_id in test_data['user_id'].unique():
        user_test_items = test_data[test_data['user_id'] == user_id]
        positive_items = user_test_items[user_test_items['rating'] > rating_threshold]['item_id'].tolist()
        if not positive_items:
            continue


        for target_item in positive_items:

            negative_items = user_test_items[user_test_items['rating'] <= rating_threshold]['item_id'].tolist()
            random.shuffle(negative_items)
            candidate_items = [target_item] + negative_items[:20]  # Limitar a 99 negativos
            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                 serendipity_items += 1
            if not len(candidate_items) >  number_negative_examples:
                interacted_items = set(data[data['user_id'] == user_id]['item_id'])
                non_interacted_items = all_item_ids - interacted_items
                filtered_items = data[data['item_id'].isin(non_interacted_items)]['item_id'].unique()
                num_items_to_select = number_negative_examples - len(candidate_items) + 1
                random_items = random.sample(list(filtered_items), num_items_to_select)
                candidate_items = candidate_items + random_items
            
            X_user = []
            items_id_list = []
            for item_id in candidate_items:
                user_idx = train_user_id_map.get(user_id)
                item_idx = train_item_id_map.get(item_id)
                user_embedding = user_embeddings[user_idx]if user_idx is not None else default_user_embedding
                item_embedding = item_embeddings_mf[item_idx] if item_idx is not None else default_item_embedding_svd
                item_embedding_bert = item_embeddings_dict[item_id]
                item_final = np.hstack((item_embedding_bert, item_embedding))
                
                #calculate serendipity using the serendipity classifier
                serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
                serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
                
                # favour serenpity interactions
                serendipity_weight = 1 + serendipit_pred
                item_final = item_final * serendipity_weight
            
                # add serendipity as a feature
                serendipity_feature = np.array([serendipit_pred]).reshape(1, -1).flatten()
                
                combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
                X_user.append(combined_embedding)
                items_id_list.append(item_id)
        
            X_user = np.array(X_user)
            y_score = xgb_model.predict(X_user)
        
            predicted_ratings = pd.DataFrame({
                'item_id': candidate_items,
                'predicted_rating': y_score
            })
        
            predicted_ratings = predicted_ratings.sort_values(by='predicted_rating', ascending=False)
            ordered_items = predicted_ratings['item_id'].tolist()
            hr = hit_rate_at_k(ordered_items, [target_item], k)
            ndcg = ndcg_at_k(ordered_items, [target_item], k)
            hr_values.append(hr)
            ndcg_values.append(ndcg)

            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                serendipity_survival_items += 1
                hr = hit_rate_at_k(ordered_items, [target_item], k)
                ndcg = ndcg_at_k(ordered_items, [target_item], k)
                hr_seren_values.append(hr)
                ndcg_seren_values.append(ndcg)

        
    average_hr = np.mean(hr_values)
    average_ndcg = np.mean(ndcg_values)
    average_hr_seren = np.mean(hr_seren_values)
    average_ndcg_seren = np.mean(ndcg_seren_values)
    
    print(f"Average HR@{k}: {average_hr}")
    print(f"Average NDCG@{k}: {average_ndcg}")
    print(f"Average HR_seren@{k}: {average_hr_seren}")
    print(f"Average NDCG_seren@{k}: {average_ndcg_seren}")
# Out:
# Average HR@5: 0.267005076142132
# Average NDCG@5: 0.16086740279286108
# Average HR_seren@5: 0.2826086956521739
# Average NDCG_seren@5: 0.17370039225276138
# Average HR@10: 0.3898477157360406
# Average NDCG@10: 0.19789770805246895
# Average HR_seren@10: 0.3858695652173913
# Average NDCG_seren@10: 0.20238962490473295
