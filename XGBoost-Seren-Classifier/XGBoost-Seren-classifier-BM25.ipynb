# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from sklearn.metrics import precision_score, recall_score, accuracy_score, mean_squared_error, mean_absolute_error
import optuna
import xgboost as xgb
import numpy as np

train_data = pd.read_csv('../train_data.csv', dtype={'item_id': str}, sep=';')
test_data = pd.read_csv('../test_data.csv', dtype={'item_id': str}, sep=';')
data = pd.read_csv('../Data/serenlens_with_features_cleaned_filtered.csv', dtype={'item_id': str}, sep=";")
all_item_ids = data['item_id'].unique()

# load serendipity classifier model
predict_serendipity = xgb.XGBClassifier()
predict_serendipity.load_model('../serendipity_classifier/serendipity_classifier_BM25.json')

def load_embeddings(embedding_path, item_ids):
    embeddings = np.load(embedding_path)
    return {item_id: normalize(embedding.reshape(1, -1)).flatten() for item_id, embedding in zip(item_ids, embeddings)}

train_user_ids = train_data['user_id'].unique()
train_item_ids = train_data['item_id'].unique()
train_user_id_map = {user_id: idx for idx, user_id in enumerate(train_user_ids)}
train_item_id_map = {item_id: idx for idx, item_id in enumerate(train_item_ids)}

interaction_matrix = train_data.pivot(index='user_id', columns='item_id', values='rating').fillna(0)
svd = TruncatedSVD(n_components=50, random_state=42)
user_embeddings = svd.fit_transform(interaction_matrix)
item_embeddings_mf = svd.components_.T

scaler = StandardScaler()
user_embeddings = scaler.fit_transform(user_embeddings)
item_embeddings_mf = scaler.fit_transform(item_embeddings_mf)

# description embeddings
item_embeddings_dict = load_embeddings('../embeddings/bm25_embeddings.npy', all_item_ids)

# default embedding for missing embeddings in test
default_user_embedding = np.mean(user_embeddings, axis=0)
default_item_embedding_svd = np.mean(item_embeddings_mf, axis=0)

default_user_embedding = normalize(default_user_embedding.reshape(1, -1)).flatten()
default_item_embedding_svd = normalize(default_item_embedding_svd.reshape(1, -1)).flatten()

train_data_samples = []

for idx, row in train_data.iterrows():
    user_idx = train_user_id_map.get(row['user_id'])
    item_idx = train_item_id_map.get(row['item_id'])
    user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
    item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
    item_embedding_bert = item_embeddings_dict[row['item_id']]
    item_final = np.hstack((item_embedding_bert, item_embedding))

    #calculate serendipity using the serendipity classifier
    serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
    serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
    serendipity_class = (serendipit_pred >= 0.5).astype(int)
    
    # favour serenpity interactions
    serendipity_weight = 3.0 if serendipity_class == 1 else 1.0
    item_final = item_final * serendipity_weight

    # add serendipity as a feature
    serendipity_feature = np.array([1]) if serendipity_class == 1 else np.array([0])
    
    combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
    train_data_samples.append((combined_embedding, row['rating']))


X_train, y_train = zip(*train_data_samples)
X_train = np.array(X_train)
y_train = np.array(y_train)

test_data_samples = []
for idx, row in test_data.iterrows():
    user_idx = train_user_id_map.get(row['user_id'])
    item_idx = train_item_id_map.get(row['item_id'])
    user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
    item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
    item_embedding_bert = item_embeddings_dict[row['item_id']]
    item_final = np.hstack((item_embedding_bert, item_embedding))


    #calculate serendipity using the serendipity classifier
    #consider in tests as if the real-world example would calculate it in order to integrate new interactions in the system
    serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
    serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
    serendipity_class = (serendipit_pred >= 0.5).astype(int)
    
    # favour serenpity interactions
    serendipity_weight = 3.0 if serendipity_class == 1 else 1.0
    item_final = item_final * serendipity_weight

    serendipity_feature = np.array([1]) if serendipity_class == 1 else np.array([0]) 
    
    combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
    test_data_samples.append((combined_embedding, row['rating']))

X_test, y_test = zip(*test_data_samples)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

def objective(trial):
    param = {
        'objective': 'reg:squarederror',
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
    }
    
    xgb_model = xgb.XGBRegressor(**param)
    
    X_train_opt, X_valid_opt, y_train_opt, y_valid_opt = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    
    xgb_model.fit(X_train_opt, y_train_opt, eval_set=[(X_valid_opt, y_valid_opt)], verbose=False)
    
    y_pred = xgb_model.predict(X_valid_opt)
    
    mse = mean_squared_error(y_valid_opt, y_pred)
    
    # minimize mse    
    return mse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print("best hyperparameters found:")
print(study.best_params)

# use best hyperparameters
best_params = study.best_params
xgb_model = xgb.XGBRegressor(**best_params)
xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=True)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'test MSE: {mse}')
print(f'test MAE: {mae}')
# Out:
# [I 2024-09-11 23:05:02,255] A new study created in memory with name: no-name-38a328e5-f9b9-4c44-bfb7-893853e625ea
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg

# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 23:24:16,219] Trial 5 finished with value: 0.8176128268241882 and parameters: {'n_estimators': 266, 'max_depth': 9, 'learning_rate': 0.055770816040712795, 'subsample': 0.9064043904846972, 'colsample_bytree': 0.6928489200643304, 'reg_alpha': 0.8293727335627804, 'reg_lambda': 1.190271157238147}. Best is trial 1 with value: 0.7946308255195618.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 23:25:58,080] Trial 6 finished with value: 0.7933958768844604 and parameters: {'n_estimators': 240, 'max_depth': 6, 'learning_rate': 0.014334307284110264, 'subsample': 0.6808872725209287, 'colsample_bytree': 0.9045946615895442, 'reg_alpha': 0.14782813762959934, 'reg_lambda': 0.11556440382035582}. Best is trial 6 with value: 0.7933958768844604.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 23:33:05,597] Trial 7 finished with value: 0.7986262440681458 and parameters: {'n_estimators': 340, 'max_depth': 9, 'learning_rate': 0.021110640009801708, 'subsample': 0.7132197130958803, 'colsample_bytree': 0.9553335022430439, 'reg_alpha': 0.3594283016504316, 'reg_lambda': 6.428764337994035}. Best is trial 6 with value: 0.7933958768844604.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 23:36:09,802] Trial 8 finished with value: 0.8111115097999573 and parameters: {'n_estimators': 138, 'max_depth': 9, 'learning_rate': 0.05439427644506229, 'subsample': 0.9466507372408529, 'colsample_bytree': 0.9599389070439213, 'reg_alpha': 0.8381964501373915, 'reg_lambda': 7.690008690803249}. Best is trial 6 with value: 0.7933958768844604.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 23:38:05,802] Trial 9 finished with value: 0.7872330546379089 and parameters: {'n_estimators': 282, 'max_depth': 6, 'learning_rate': 0.018555608090287685, 'subsample': 0.7884754867867466, 'colsample_bytree': 0.6957671517540271, 'reg_alpha': 1.423365125517825, 'reg_lambda': 0.1313779843500792}. Best is trial 9 with value: 0.7872330546379089.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel
FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-12 00:08:36,850] Trial 19 finished with value: 0.8243599534034729 and parameters: {'n_estimators': 490, 'max_depth': 7, 'learning_rate': 0.04104957654954762, 'subsample': 0.6012973680666844, 'colsample_bytree': 0.6719820716380004, 'reg_alpha': 9.824721079897838, 'reg_lambda': 2.7528886678715794}. Best is trial 11 with value: 0.7843871116638184.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-12 00:09:54,149] Trial 20 finished with value: 0.7921189665794373 and parameters: {'n_estimators': 248, 'max_depth': 5, 'learning_rate': 0.014470512146138322, 'subsample': 0.8889803429118832, 'colsample_bytree': 0.7264901938963741, 'reg_alpha': 1.4110617297639867, 'reg_lambda': 0.2477026936748405}. Best is trial 11 with value: 0.7843871116638184.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-12 00:12:05,915] Trial 21 finished with value: 0.7879472374916077 and parameters: {'n_estimators': 209, 'max_depth': 7, 'learning_rate': 0.010120442392761577, 'subsample': 0.825017714399207, 'colsample_bytree': 0.7958320373815202, 'reg_alpha': 2.544630741714064, 'reg_lambda': 0.16630873785067762}. Best is trial 11 with value: 0.7843871116638184.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-12 00:15:19,600] Trial 22 finished with value: 0.7915648221969604 and parameters: {'n_estimators': 220, 'max_depth': 8, 'learning_rate': 0.01374050178679213, 'subsample': 0.8331003002826775, 'colsample_bytree': 0.809708669950164, 'reg_alpha': 2.551188543347534, 'reg_lambda': 0.6412510632048728}. Best is trial 11 with value: 0.7843871116638184.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# ...
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-12 01:16:37,151] Trial 47 finished with value: 0.7859126329421997 and parameters: {'n_estimators': 322, 'max_depth': 7, 'learning_rate': 0.013211679292529793, 'subsample': 0.8872052912373473, 'colsample_bytree': 0.7437796256104776, 'reg_alpha': 0.1468181491850136, 'reg_lambda': 0.1971615200537667}. Best is trial 32 with value: 0.7834675312042236.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-12 01:22:30,333] Trial 48 finished with value: 0.8711081147193909 and parameters: {'n_estimators': 321, 'max_depth': 9, 'learning_rate': 0.16685324308653365, 'subsample': 0.8939301742051041, 'colsample_bytree': 0.7530605182125287, 'reg_alpha': 0.12769722856986634, 'reg_lambda': 0.20622336728790008}. Best is trial 32 with value: 0.7834675312042236.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_20308\1423387168.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-12 01:26:27,670] Trial 49 finished with value: 0.7879868745803833 and parameters: {'n_estimators': 305, 'max_depth': 8, 'learning_rate': 0.011632298340240434, 'subsample': 0.8571066680489462, 'colsample_bytree': 0.8096327793498909, 'reg_alpha': 0.17143519765772186, 'reg_lambda': 0.4013667147318586}. Best is trial 32 with value: 0.7834675312042236.
# best hyperparameters found:
# {'n_estimators': 329, 'max_depth': 7, 'learning_rate': 0.012175480169344237, 'subsample': 0.8378182967731923, 'colsample_bytree': 0.8549209120360121, 'reg_alpha': 1.3875061986903485, 'reg_lambda': 0.31769230881816857}
# [0]	validation_0-rmse:0.94712
# [1]	validation_0-rmse:0.94646
# [2]	validation_0-rmse:0.94575
# [3]	validation_0-rmse:0.94503
# [4]	validation_0-rmse:0.94434
# [5]	validation_0-rmse:0.94366
# [6]	validation_0-rmse:0.94323
# [7]	validation_0-rmse:0.94253
# [8]	validation_0-rmse:0.94200
# [9]	validation_0-rmse:0.94128
# [10]	validation_0-rmse:0.94065
# [11]	validation_0-rmse:0.93982
# [12]	validation_0-rmse:0.93910
# [13]	validation_0-rmse:0.93857
# [14]	validation_0-rmse:0.93781
# [15]	validation_0-rmse:0.93705
# [16]	validation_0-rmse:0.93615
# [17]	validation_0-rmse:0.93551
# [18]	validation_0-rmse:0.93510
# [19]	validation_0-rmse:0.93452
# [20]	validation_0-rmse:0.93413
# [21]	validation_0-rmse:0.93359
# [22]	validation_0-rmse:0.93309
# [23]	validation_0-rmse:0.93253
# [24]	validation_0-rmse:0.93210
# [25]	validation_0-rmse:0.93162
# [26]	validation_0-rmse:0.93103
# [27]	validation_0-rmse:0.93055
# [28]	validation_0-rmse:0.93018
# [29]	validation_0-rmse:0.92961
# [30]	validation_0-rmse:0.92918
# [31]	validation_0-rmse:0.92873
# [32]	validation_0-rmse:0.92834
# [33]	validation_0-rmse:0.92797
# [34]	validation_0-rmse:0.92755
# [35]	validation_0-rmse:0.92720
# [36]	validation_0-rmse:0.92658
# [37]	validation_0-rmse:0.92619
# [38]	validation_0-rmse:0.92591
# [39]	validation_0-rmse:0.92562
# [40]	validation_0-rmse:0.92532
# [41]	validation_0-rmse:0.92490
# [42]	validation_0-rmse:0.92461
# [43]	validation_0-rmse:0.92435
# [44]	validation_0-rmse:0.92412
# [45]	validation_0-rmse:0.92377
# [46]	validation_0-rmse:0.92342
# [47]	validation_0-rmse:0.92312
# [48]	validation_0-rmse:0.92278
# [49]	validation_0-rmse:0.92243
# [50]	validation_0-rmse:0.92195
# [51]	validation_0-rmse:0.92168
# [52]	validation_0-rmse:0.92136
# [53]	validation_0-rmse:0.92109
# [54]	validation_0-rmse:0.92084
# [55]	validation_0-rmse:0.92071
# [56]	validation_0-rmse:0.92059
# [57]	validation_0-rmse:0.92029
# [58]	validation_0-rmse:0.92003
# [59]	validation_0-rmse:0.91983
# [60]	validation_0-rmse:0.91966
# [61]	validation_0-rmse:0.91934
# [62]	validation_0-rmse:0.91890
# [63]	validation_0-rmse:0.91850
# [64]	validation_0-rmse:0.91844
# [65]	validation_0-rmse:0.91831
# [66]	validation_0-rmse:0.91805
# [67]	validation_0-rmse:0.91800
# [68]	validation_0-rmse:0.91785
# [69]	validation_0-rmse:0.91769
# [70]	validation_0-rmse:0.91752
# [71]	validation_0-rmse:0.91720
# [72]	validation_0-rmse:0.91699
# [73]	validation_0-rmse:0.91686
# [74]	validation_0-rmse:0.91658
# [75]	validation_0-rmse:0.91642
# [76]	validation_0-rmse:0.91633
# [77]	validation_0-rmse:0.91624
# [78]	validation_0-rmse:0.91613
# [79]	validation_0-rmse:0.91589
# [80]	validation_0-rmse:0.91577
# [81]	validation_0-rmse:0.91562
# [82]	validation_0-rmse:0.91549
# [83]	validation_0-rmse:0.91547
# [84]	validation_0-rmse:0.91535
# [85]	validation_0-rmse:0.91521
# [86]	validation_0-rmse:0.91508
# [87]	validation_0-rmse:0.91500
# [88]	validation_0-rmse:0.91486
# [89]	validation_0-rmse:0.91467
# [90]	validation_0-rmse:0.91456
# [91]	validation_0-rmse:0.91440
# [92]	validation_0-rmse:0.91432
# [93]	validation_0-rmse:0.91415
# [94]	validation_0-rmse:0.91396
# [95]	validation_0-rmse:0.91397
# [96]	validation_0-rmse:0.91393
# [97]	validation_0-rmse:0.91373
# [98]	validation_0-rmse:0.91366
# [99]	validation_0-rmse:0.91355
# [100]	validation_0-rmse:0.91349
# [101]	validation_0-rmse:0.91330
# [102]	validation_0-rmse:0.91310
# [103]	validation_0-rmse:0.91295
# [104]	validation_0-rmse:0.91298
# [105]	validation_0-rmse:0.91274
# [106]	validation_0-rmse:0.91250
# [107]	validation_0-rmse:0.91237
# [108]	validation_0-rmse:0.91227
# [109]	validation_0-rmse:0.91201
# [110]	validation_0-rmse:0.91181
# [111]	validation_0-rmse:0.91168
# [112]	validation_0-rmse:0.91159
# [113]	validation_0-rmse:0.91151
# [114]	validation_0-rmse:0.91119
# [115]	validation_0-rmse:0.91115
# [116]	validation_0-rmse:0.91115
# [117]	validation_0-rmse:0.91108
# [118]	validation_0-rmse:0.91104
# [119]	validation_0-rmse:0.91100
# [120]	validation_0-rmse:0.91103
# [121]	validation_0-rmse:0.91096
# [122]	validation_0-rmse:0.91074
# [123]	validation_0-rmse:0.91057
# [124]	validation_0-rmse:0.91058
# [125]	validation_0-rmse:0.91053
# [126]	validation_0-rmse:0.91048
# [127]	validation_0-rmse:0.91039
# [128]	validation_0-rmse:0.91023
# [129]	validation_0-rmse:0.91015
# [130]	validation_0-rmse:0.90991
# [131]	validation_0-rmse:0.90992
# [132]	validation_0-rmse:0.90975
# [133]	validation_0-rmse:0.90968
# [134]	validation_0-rmse:0.90957
# [135]	validation_0-rmse:0.90938
# [136]	validation_0-rmse:0.90935
# [137]	validation_0-rmse:0.90935
# [138]	validation_0-rmse:0.90939
# [139]	validation_0-rmse:0.90932
# [140]	validation_0-rmse:0.90919
# [141]	validation_0-rmse:0.90920
# [142]	validation_0-rmse:0.90914
# [143]	validation_0-rmse:0.90893
# [144]	validation_0-rmse:0.90890
# [145]	validation_0-rmse:0.90887
# [146]	validation_0-rmse:0.90878
# [147]	validation_0-rmse:0.90857
# [148]	validation_0-rmse:0.90847
# [149]	validation_0-rmse:0.90847
# [150]	validation_0-rmse:0.90836
# [151]	validation_0-rmse:0.90825
# [152]	validation_0-rmse:0.90829
# [153]	validation_0-rmse:0.90824
# [154]	validation_0-rmse:0.90815
# [155]	validation_0-rmse:0.90806
# [156]	validation_0-rmse:0.90809
# [157]	validation_0-rmse:0.90804
# [158]	validation_0-rmse:0.90796
# [159]	validation_0-rmse:0.90792
# [160]	validation_0-rmse:0.90791
# [161]	validation_0-rmse:0.90784
# [162]	validation_0-rmse:0.90782
# [163]	validation_0-rmse:0.90776
# [164]	validation_0-rmse:0.90773
# [165]	validation_0-rmse:0.90768
# [166]	validation_0-rmse:0.90758
# [167]	validation_0-rmse:0.90769
# [168]	validation_0-rmse:0.90768
# [169]	validation_0-rmse:0.90756
# [170]	validation_0-rmse:0.90749
# [171]	validation_0-rmse:0.90735
# [172]	validation_0-rmse:0.90723
# [173]	validation_0-rmse:0.90719
# [174]	validation_0-rmse:0.90718
# [175]	validation_0-rmse:0.90714
# [176]	validation_0-rmse:0.90698
# [177]	validation_0-rmse:0.90693
# [178]	validation_0-rmse:0.90692
# [179]	validation_0-rmse:0.90689
# [180]	validation_0-rmse:0.90682
# [181]	validation_0-rmse:0.90679
# [182]	validation_0-rmse:0.90675
# [183]	validation_0-rmse:0.90666
# [184]	validation_0-rmse:0.90653
# [185]	validation_0-rmse:0.90641
# [186]	validation_0-rmse:0.90640
# [187]	validation_0-rmse:0.90633
# [188]	validation_0-rmse:0.90624
# [189]	validation_0-rmse:0.90623
# [190]	validation_0-rmse:0.90614
# [191]	validation_0-rmse:0.90614
# [192]	validation_0-rmse:0.90607
# [193]	validation_0-rmse:0.90605
# [194]	validation_0-rmse:0.90603
# [195]	validation_0-rmse:0.90599
# [196]	validation_0-rmse:0.90602
# [197]	validation_0-rmse:0.90602
# [198]	validation_0-rmse:0.90603
# [199]	validation_0-rmse:0.90598
# [200]	validation_0-rmse:0.90601
# [201]	validation_0-rmse:0.90589
# [202]	validation_0-rmse:0.90584
# [203]	validation_0-rmse:0.90579
# [204]	validation_0-rmse:0.90581
# [205]	validation_0-rmse:0.90580
# [206]	validation_0-rmse:0.90568
# [207]	validation_0-rmse:0.90567
# [208]	validation_0-rmse:0.90572
# [209]	validation_0-rmse:0.90572
# [210]	validation_0-rmse:0.90574
# [211]	validation_0-rmse:0.90569
# [212]	validation_0-rmse:0.90564
# [213]	validation_0-rmse:0.90557
# [214]	validation_0-rmse:0.90551
# [215]	validation_0-rmse:0.90553
# [216]	validation_0-rmse:0.90557
# [217]	validation_0-rmse:0.90544
# [218]	validation_0-rmse:0.90543
# [219]	validation_0-rmse:0.90544
# [220]	validation_0-rmse:0.90540
# [221]	validation_0-rmse:0.90547
# [222]	validation_0-rmse:0.90551
# [223]	validation_0-rmse:0.90559
# [224]	validation_0-rmse:0.90559
# [225]	validation_0-rmse:0.90565
# [226]	validation_0-rmse:0.90565
# [227]	validation_0-rmse:0.90565
# [228]	validation_0-rmse:0.90567
# [229]	validation_0-rmse:0.90570
# [230]	validation_0-rmse:0.90574
# [231]	validation_0-rmse:0.90569
# [232]	validation_0-rmse:0.90566
# [233]	validation_0-rmse:0.90565
# [234]	validation_0-rmse:0.90563
# [235]	validation_0-rmse:0.90557
# [236]	validation_0-rmse:0.90555
# [237]	validation_0-rmse:0.90549
# [238]	validation_0-rmse:0.90551
# [239]	validation_0-rmse:0.90549
# [240]	validation_0-rmse:0.90551
# [241]	validation_0-rmse:0.90552
# [242]	validation_0-rmse:0.90547
# [243]	validation_0-rmse:0.90541
# [244]	validation_0-rmse:0.90535
# [245]	validation_0-rmse:0.90532
# [246]	validation_0-rmse:0.90539
# [247]	validation_0-rmse:0.90542
# [248]	validation_0-rmse:0.90530
# [249]	validation_0-rmse:0.90537
# [250]	validation_0-rmse:0.90532
# [251]	validation_0-rmse:0.90533
# [252]	validation_0-rmse:0.90529
# [253]	validation_0-rmse:0.90524
# [254]	validation_0-rmse:0.90524
# [255]	validation_0-rmse:0.90521
# [256]	validation_0-rmse:0.90523
# [257]	validation_0-rmse:0.90512
# [258]	validation_0-rmse:0.90510
# [259]	validation_0-rmse:0.90505
# [260]	validation_0-rmse:0.90499
# [261]	validation_0-rmse:0.90498
# [262]	validation_0-rmse:0.90497
# [263]	validation_0-rmse:0.90487
# [264]	validation_0-rmse:0.90487
# [265]	validation_0-rmse:0.90482
# [266]	validation_0-rmse:0.90482
# [267]	validation_0-rmse:0.90471
# [268]	validation_0-rmse:0.90480
# [269]	validation_0-rmse:0.90477
# [270]	validation_0-rmse:0.90475
# [271]	validation_0-rmse:0.90466
# [272]	validation_0-rmse:0.90469
# [273]	validation_0-rmse:0.90478
# [274]	validation_0-rmse:0.90490
# [275]	validation_0-rmse:0.90489
# [276]	validation_0-rmse:0.90492
# [277]	validation_0-rmse:0.90490
# [278]	validation_0-rmse:0.90491
# [279]	validation_0-rmse:0.90492
# [280]	validation_0-rmse:0.90492
# [281]	validation_0-rmse:0.90492
# [282]	validation_0-rmse:0.90492
# [283]	validation_0-rmse:0.90498
# [284]	validation_0-rmse:0.90494
# [285]	validation_0-rmse:0.90496
# [286]	validation_0-rmse:0.90487
# [287]	validation_0-rmse:0.90491
# [288]	validation_0-rmse:0.90499
# [289]	validation_0-rmse:0.90500
# [290]	validation_0-rmse:0.90502
# [291]	validation_0-rmse:0.90504
# [292]	validation_0-rmse:0.90502
# [293]	validation_0-rmse:0.90508
# [294]	validation_0-rmse:0.90508
# [295]	validation_0-rmse:0.90510
# [296]	validation_0-rmse:0.90510
# [297]	validation_0-rmse:0.90510
# [298]	validation_0-rmse:0.90518
# [299]	validation_0-rmse:0.90514
# [300]	validation_0-rmse:0.90521
# [301]	validation_0-rmse:0.90525
# [302]	validation_0-rmse:0.90533
# [303]	validation_0-rmse:0.90533
# [304]	validation_0-rmse:0.90533
# [305]	validation_0-rmse:0.90537
# [306]	validation_0-rmse:0.90534
# [307]	validation_0-rmse:0.90530
# [308]	validation_0-rmse:0.90529
# [309]	validation_0-rmse:0.90527
# [310]	validation_0-rmse:0.90525
# [311]	validation_0-rmse:0.90527
# [312]	validation_0-rmse:0.90529
# [313]	validation_0-rmse:0.90529
# [314]	validation_0-rmse:0.90536
# [315]	validation_0-rmse:0.90529
# [316]	validation_0-rmse:0.90534
# [317]	validation_0-rmse:0.90538
# [318]	validation_0-rmse:0.90540
# [319]	validation_0-rmse:0.90550
# [320]	validation_0-rmse:0.90558
# [321]	validation_0-rmse:0.90564
# [322]	validation_0-rmse:0.90560
# [323]	validation_0-rmse:0.90569
# [324]	validation_0-rmse:0.90564
# [325]	validation_0-rmse:0.90566
# [326]	validation_0-rmse:0.90564
# [327]	validation_0-rmse:0.90559
# [328]	validation_0-rmse:0.90560
# test MSE: 0.8201034069061279
# test MAE: 0.7017519474029541

# %%
import numpy as np
import random

def hit_rate_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    hits = len(set(predicted_at_k) & set(true_items))
    return 1.0 if hits > 0 else 0.0

def ndcg_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    dcg = 0.0
    idcg = sum((1.0 / np.log2(i + 2) for i in range(min(len(true_items), k))))
    
    for i, item in enumerate(predicted_at_k):
        if item in true_items:
            dcg += 1.0 / np.log2(i + 2)  # Log base 2

    return dcg / idcg if idcg > 0 else 0.0

hr_values = []
ndcg_values = []
hr_seren_values = []
ndcg_seren_values = []
rating_threshold = 3
serendipity_items = 0
serendipity_survival_items = 0
all_item_ids = set(all_item_ids)
number_negative_examples = 20
for k in [5,10]:
    for user_id in test_data['user_id'].unique():
        user_test_items = test_data[test_data['user_id'] == user_id]
        positive_items = user_test_items[user_test_items['rating'] > rating_threshold]['item_id'].tolist()
        if not positive_items:
            continue


        for target_item in positive_items:

            negative_items = user_test_items[user_test_items['rating'] <= rating_threshold]['item_id'].tolist()
            random.shuffle(negative_items)
            candidate_items = [target_item] + negative_items[:20]  # Limitar a 99 negativos
            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                 serendipity_items += 1
            if not len(candidate_items) >  number_negative_examples:
                interacted_items = set(data[data['user_id'] == user_id]['item_id'])
                non_interacted_items = all_item_ids - interacted_items
                filtered_items = data[data['item_id'].isin(non_interacted_items)]['item_id'].unique()
                num_items_to_select = number_negative_examples - len(candidate_items) + 1
                random_items = random.sample(list(filtered_items), num_items_to_select)
                candidate_items = candidate_items + random_items
            
            X_user = []
            items_id_list = []
            for item_id in candidate_items:
                user_idx = train_user_id_map.get(user_id)
                item_idx = train_item_id_map.get(item_id)
                user_embedding = user_embeddings[user_idx]if user_idx is not None else default_user_embedding
                item_embedding = item_embeddings_mf[item_idx] if item_idx is not None else default_item_embedding_svd
                item_embedding_bert = item_embeddings_dict[item_id]
                item_final = np.hstack((item_embedding_bert, item_embedding))
                
                #calculate serendipity using the serendipity classifier
                #consider in tests as if the real-world example would calculate it in order to integrate new interactions in the system
                serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
                serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
                serendipity_class = (serendipit_pred >= 0.5).astype(int)
                
                serendipity_weight = 3.0 if serendipity_class == 1 else 1.0
                item_final = item_final * serendipity_weight
            
                serendipity_feature = np.array([1]) if serendipity_class == 1 else np.array([0])
                
                combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
                X_user.append(combined_embedding)
                items_id_list.append(item_id)
        
            X_user = np.array(X_user)
            y_score = xgb_model.predict(X_user)
        
            predicted_ratings = pd.DataFrame({
                'item_id': candidate_items,
                'predicted_rating': y_score
            })
        
            predicted_ratings = predicted_ratings.sort_values(by='predicted_rating', ascending=False)
            ordered_items = predicted_ratings['item_id'].tolist()
            hr = hit_rate_at_k(ordered_items, [target_item], k)
            ndcg = ndcg_at_k(ordered_items, [target_item], k)
            hr_values.append(hr)
            ndcg_values.append(ndcg)

            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                serendipity_survival_items += 1
                hr = hit_rate_at_k(ordered_items, [target_item], k)
                ndcg = ndcg_at_k(ordered_items, [target_item], k)
                hr_seren_values.append(hr)
                ndcg_seren_values.append(ndcg)

        
    average_hr = np.mean(hr_values)
    average_ndcg = np.mean(ndcg_values)
    average_hr_seren = np.mean(hr_seren_values)
    average_ndcg_seren = np.mean(ndcg_seren_values)
    
    print(f"Average HR@{k}: {average_hr}")
    print(f"Average NDCG@{k}: {average_ndcg}")
    print(f"Average HR_seren@{k}: {average_hr_seren}")
    print(f"Average NDCG_seren@{k}: {average_ndcg_seren}")
# Out:
# Average HR@5: 0.22081218274111675
# Average NDCG@5: 0.12909098426102417
# Average HR_seren@5: 0.2608695652173913
# Average NDCG_seren@5: 0.16175526062168774
# Average HR@10: 0.349238578680203
# Average NDCG@10: 0.17115582911759555
# Average HR_seren@10: 0.375
# Average NDCG_seren@10: 0.19056169871787393
