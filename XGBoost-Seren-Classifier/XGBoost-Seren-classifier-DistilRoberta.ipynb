# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from sklearn.metrics import precision_score, recall_score, accuracy_score, mean_squared_error, mean_absolute_error
import optuna
import xgboost as xgb
import numpy as np

train_data = pd.read_csv('../train_data.csv', dtype={'item_id': str}, sep=';')
test_data = pd.read_csv('../test_data.csv', dtype={'item_id': str}, sep=';')
data = pd.read_csv('../Data/serenlens_with_features_cleaned_filtered.csv', dtype={'item_id': str}, sep=";")
all_item_ids = data['item_id'].unique()

# load serendipity classifier model
predict_serendipity = xgb.XGBClassifier()
predict_serendipity.load_model('../serendipity_classifier/serendipity_classifier_distilroberta.json')

def load_embeddings(embedding_path, item_ids):
    embeddings = np.load(embedding_path)
    return {item_id: normalize(embedding.reshape(1, -1)).flatten() for item_id, embedding in zip(item_ids, embeddings)}

train_user_ids = train_data['user_id'].unique()
train_item_ids = train_data['item_id'].unique()
train_user_id_map = {user_id: idx for idx, user_id in enumerate(train_user_ids)}
train_item_id_map = {item_id: idx for idx, item_id in enumerate(train_item_ids)}

interaction_matrix = train_data.pivot(index='user_id', columns='item_id', values='rating').fillna(0)
svd = TruncatedSVD(n_components=50, random_state=42)
user_embeddings = svd.fit_transform(interaction_matrix)
item_embeddings_mf = svd.components_.T

scaler = StandardScaler()
user_embeddings = scaler.fit_transform(user_embeddings)
item_embeddings_mf = scaler.fit_transform(item_embeddings_mf)

# description embeddings
item_embeddings_dict = load_embeddings('../embeddings/distilroberta_embeddings.npy', all_item_ids)

# default embedding for missing embeddings in test
default_user_embedding = np.mean(user_embeddings, axis=0)
default_item_embedding_svd = np.mean(item_embeddings_mf, axis=0)

default_user_embedding = normalize(default_user_embedding.reshape(1, -1)).flatten()
default_item_embedding_svd = normalize(default_item_embedding_svd.reshape(1, -1)).flatten()

train_data_samples = []

for idx, row in train_data.iterrows():
    user_idx = train_user_id_map.get(row['user_id'])
    item_idx = train_item_id_map.get(row['item_id'])
    user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
    item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
    item_embedding_bert = item_embeddings_dict[row['item_id']]
    item_final = np.hstack((item_embedding_bert, item_embedding))

    #calculate serendipity using the serendipity classifier
    serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
    serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
    serendipity_class = (serendipit_pred >= 0.5).astype(int)
    
    # favour serenpity interactions
    serendipity_weight = 3.0 if serendipity_class == 1 else 1.0
    item_final = item_final * serendipity_weight

    # add serendipity as a feature
    serendipity_feature = np.array([1]) if serendipity_class == 1 else np.array([0])
    
    combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
    train_data_samples.append((combined_embedding, row['rating']))


X_train, y_train = zip(*train_data_samples)
X_train = np.array(X_train)
y_train = np.array(y_train)

test_data_samples = []
for idx, row in test_data.iterrows():
    user_idx = train_user_id_map.get(row['user_id'])
    item_idx = train_item_id_map.get(row['item_id'])
    user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
    item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
    item_embedding_bert = item_embeddings_dict[row['item_id']]
    item_final = np.hstack((item_embedding_bert, item_embedding))


    #calculate serendipity using the serendipity classifier
    #consider in tests as if the real-world example would calculate it in order to integrate new interactions in the system
    serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
    serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
    serendipity_class = (serendipit_pred >= 0.5).astype(int)
    
    # favour serenpity interactions
    serendipity_weight = 3.0 if serendipity_class == 1 else 1.0
    item_final = item_final * serendipity_weight

    serendipity_feature = np.array([1]) if serendipity_class == 1 else np.array([0]) 
    
    combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
    test_data_samples.append((combined_embedding, row['rating']))

X_test, y_test = zip(*test_data_samples)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

def objective(trial):
    param = {
        'objective': 'reg:squarederror',
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
    }
    
    xgb_model = xgb.XGBRegressor(**param)
    
    X_train_opt, X_valid_opt, y_train_opt, y_valid_opt = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    
    xgb_model.fit(X_train_opt, y_train_opt, eval_set=[(X_valid_opt, y_valid_opt)], verbose=False)
    
    y_pred = xgb_model.predict(X_valid_opt)
    
    mse = mean_squared_error(y_valid_opt, y_pred)
    
    # minimize mse    
    return mse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print("best hyperparameters found:")
print(study.best_params)

# use best hyperparameters
best_params = study.best_params
xgb_model = xgb.XGBRegressor(**best_params)
xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=True)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'test MSE: {mse}')
print(f'test MAE: {mae}')
# Out:
# [I 2024-09-11 21:34:44,839] A new study created in memory with name: no-name-f3331f36-64c4-4861-9951-d3d900cb5bef
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:34:56,193] Trial 0 finished with value: 0.8090540170669556 and parameters: {'n_estimators': 279, 'max_depth': 6, 'learning_rate': 0.062477863674583814, 'subsample': 0.6680981663587483, 'colsample_bytree': 0.773228910695097, 'reg_alpha': 4.910152887924567, 'reg_lambda': 0.6292288751654738}. Best is trial 0 with value: 0.8090540170669556.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:35:01,335] Trial 1 finished with value: 0.8115586042404175 and parameters: {'n_estimators': 363, 'max_depth': 3, 'learning_rate': 0.15444939718811773, 'subsample': 0.9091174224988385, 'colsample_bytree': 0.944674608796134, 'reg_alpha': 9.338852161283137, 'reg_lambda': 8.444129296116607}. Best is trial 0 with value: 0.8090540170669556.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:35:14,453] Trial 2 finished with value: 0.785416841506958 and parameters: {'n_estimators': 322, 'max_depth': 6, 'learning_rate': 0.035548587323872574, 'subsample': 0.6518266042360182, 'colsample_bytree': 0.8603756920796891, 'reg_alpha': 0.2412763417966299, 'reg_lambda': 3.7061644497620114}. Best is trial 2 with value: 0.785416841506958.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:35:18,410] Trial 3 finished with value: 0.7884607911109924 and parameters: {'n_estimators': 202, 'max_depth': 4, 'learning_rate': 0.023263460564510723, 'subsample': 0.8227090740197462, 'colsample_bytree': 0.993500985558874, 'reg_alpha': 0.7719668658924876, 'reg_lambda': 3.708436440555015}. Best is trial 2 with value: 0.785416841506958.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:35:36,573] Trial 4 finished with value: 0.7899636626243591 and parameters: {'n_estimators': 116, 'max_depth': 9, 'learning_rate': 0.01050491194648122, 'subsample': 0.9715528533183042, 'colsample_bytree': 0.930269111862218, 'reg_alpha': 0.4206842792704911, 'reg_lambda': 0.10896114175295336}. Best is trial 2 with value: 0.785416841506958.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:35:48,397] Trial 5 finished with value: 0.8340417742729187 and parameters: {'n_estimators': 193, 'max_depth': 8, 'learning_rate': 0.19627597681953335, 'subsample': 0.8851953180198808, 'colsample_bytree': 0.623880474489319, 'reg_alpha': 8.134695175490842, 'reg_lambda': 3.4469867936813845}. Best is trial 2 with value: 0.785416841506958.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:36:51,776] Trial 6 finished with value: 0.783353865146637 and parameters: {'n_estimators': 432, 'max_depth': 9, 'learning_rate': 0.019095919549117435, 'subsample': 0.6100249060739978, 'colsample_bytree': 0.8465696568157278, 'reg_alpha': 0.12055298549520001, 'reg_lambda': 4.27824777694616}. Best is trial 6 with value: 0.783353865146637.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:37:28,534] Trial 7 finished with value: 0.852507472038269 and parameters: {'n_estimators': 229, 'max_depth': 9, 'learning_rate': 0.12566268193078614, 'subsample': 0.6125108268377754, 'colsample_bytree': 0.9617127781774921, 'reg_alpha': 0.24546827063666893, 'reg_lambda': 1.8403356638358714}. Best is trial 6 with value: 0.783353865146637.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:38:04,107] Trial 8 finished with value: 0.7818055152893066 and parameters: {'n_estimators': 385, 'max_depth': 8, 'learning_rate': 0.014625026599511131, 'subsample': 0.8977671020674605, 'colsample_bytree': 0.6173537159923282, 'reg_alpha': 0.7179135560237765, 'reg_lambda': 4.685530645702747}. Best is trial 8 with value: 0.7818055152893066.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:38:29,679] Trial 9 finished with value: 0.7881242632865906 and parameters: {'n_estimators': 418, 'max_depth': 7, 'learning_rate': 0.0323212138853494, 'subsample': 0.6312902730966318, 'colsample_bytree': 0.6886722895488634, 'reg_alpha': 0.5836798193188861, 'reg_lambda': 8.23262844758964}. Best is trial 8 with value: 0.7818055152893066.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:39:57,618] Trial 10 finished with value: 0.7778677940368652 and parameters: {'n_estimators': 471, 'max_depth': 10, 'learning_rate': 0.010612932236591627, 'subsample': 0.7669555128705218, 'colsample_bytree': 0.6058269105214787, 'reg_alpha': 2.3442154528289985, 'reg_lambda': 0.5898724607866564}. Best is trial 10 with value: 0.7778677940368652.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:41:28,828] Trial 11 finished with value: 0.7774136662483215 and parameters: {'n_estimators': 490, 'max_depth': 10, 'learning_rate': 0.010720040996974572, 'subsample': 0.7481022819253482, 'colsample_bytree': 0.6134834893023164, 'reg_alpha': 1.951492827642481, 'reg_lambda': 0.5056876281963596}. Best is trial 11 with value: 0.7774136662483215.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:43:03,072] Trial 12 finished with value: 0.7773765921592712 and parameters: {'n_estimators': 496, 'max_depth': 10, 'learning_rate': 0.011444281633364506, 'subsample': 0.7307224353125716, 'colsample_bytree': 0.7032855170447011, 'reg_alpha': 2.3857927373451555, 'reg_lambda': 0.4647081994591821}. Best is trial 12 with value: 0.7773765921592712.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:43:53,847] Trial 13 finished with value: 0.8227024674415588 and parameters: {'n_estimators': 491, 'max_depth': 10, 'learning_rate': 0.08005190237837267, 'subsample': 0.7335485282317216, 'colsample_bytree': 0.7005969358834789, 'reg_alpha': 1.893373585808767, 'reg_lambda': 0.23208443932340728}. Best is trial 12 with value: 0.7773765921592712.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:45:12,994] Trial 14 finished with value: 0.7944784164428711 and parameters: {'n_estimators': 498, 'max_depth': 10, 'learning_rate': 0.03433438143083105, 'subsample': 0.703211375437907, 'colsample_bytree': 0.6966064978736835, 'reg_alpha': 1.7684971939208658, 'reg_lambda': 0.30666104750031303}. Best is trial 12 with value: 0.7773765921592712.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:45:24,883] Trial 15 finished with value: 0.7769759297370911 and parameters: {'n_estimators': 440, 'max_depth': 5, 'learning_rate': 0.01629616705076289, 'subsample': 0.8080445622791611, 'colsample_bytree': 0.7628890015045932, 'reg_alpha': 3.2913206463600124, 'reg_lambda': 1.1470598996718198}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:45:36,101] Trial 16 finished with value: 0.7773267030715942 and parameters: {'n_estimators': 433, 'max_depth': 5, 'learning_rate': 0.017427714460844387, 'subsample': 0.8104932977987107, 'colsample_bytree': 0.7560092912886418, 'reg_alpha': 3.9530495952184506, 'reg_lambda': 1.5057968198156613}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:45:45,553] Trial 17 finished with value: 0.783650279045105 and parameters: {'n_estimators': 343, 'max_depth': 5, 'learning_rate': 0.021190405555871542, 'subsample': 0.8251713325247828, 'colsample_bytree': 0.7754206832743936, 'reg_alpha': 4.711107302194051, 'reg_lambda': 1.3152800159931257}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:45:53,491] Trial 18 finished with value: 0.7936946749687195 and parameters: {'n_estimators': 424, 'max_depth': 4, 'learning_rate': 0.04943238747645091, 'subsample': 0.7887133483579851, 'colsample_bytree': 0.8475467546850856, 'reg_alpha': 4.282120336958789, 'reg_lambda': 1.8167145406475589}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:46:00,893] Trial 19 finished with value: 0.7778565883636475 and parameters: {'n_estimators': 290, 'max_depth': 5, 'learning_rate': 0.016942114963965742, 'subsample': 0.8515405951178612, 'colsample_bytree': 0.737393963716389, 'reg_alpha': 1.1781125548147995, 'reg_lambda': 0.953692701019324}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:46:06,425] Trial 20 finished with value: 0.8241119384765625 and parameters: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.2710795516856987, 'subsample': 0.9584768941870176, 'colsample_bytree': 0.8129116208054457, 'reg_alpha': 3.1994060238062882, 'reg_lambda': 1.03734950962377}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:46:18,505] Trial 21 finished with value: 0.7787376642227173 and parameters: {'n_estimators': 457, 'max_depth': 5, 'learning_rate': 0.014157745728595262, 'subsample': 0.7234108864112179, 'colsample_bytree': 0.7347681930647544, 'reg_alpha': 3.4057520606836835, 'reg_lambda': 0.3027842940351174}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:46:45,818] Trial 22 finished with value: 0.7870170474052429 and parameters: {'n_estimators': 447, 'max_depth': 7, 'learning_rate': 0.027161069960868353, 'subsample': 0.7862605274694606, 'colsample_bytree': 0.673343660286123, 'reg_alpha': 1.234410773379427, 'reg_lambda': 2.0489836119807325}. Best is trial 15 with value: 0.7769759297370911.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# ...
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:56:51,674] Trial 48 finished with value: 0.7915316820144653 and parameters: {'n_estimators': 481, 'max_depth': 6, 'learning_rate': 0.03652465018611592, 'subsample': 0.8836902086917788, 'colsample_bytree': 0.9741885656044498, 'reg_alpha': 0.6339696944529123, 'reg_lambda': 0.14749176060020605}. Best is trial 34 with value: 0.7711818218231201.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:122: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:123: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:124: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_2416\876088729.py:125: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-11 21:57:21,067] Trial 49 finished with value: 0.7934707403182983 and parameters: {'n_estimators': 437, 'max_depth': 7, 'learning_rate': 0.028363345818283436, 'subsample': 0.9159310099591053, 'colsample_bytree': 0.9534622102679475, 'reg_alpha': 0.9172989323638113, 'reg_lambda': 0.2765516122450312}. Best is trial 34 with value: 0.7711818218231201.
# best hyperparameters found:
# {'n_estimators': 398, 'max_depth': 6, 'learning_rate': 0.021558587422623253, 'subsample': 0.9410780257527024, 'colsample_bytree': 0.8933745445712644, 'reg_alpha': 1.5688228130545614, 'reg_lambda': 0.5931889119123094}
# [0]	validation_0-rmse:0.94680
# [1]	validation_0-rmse:0.94548
# [2]	validation_0-rmse:0.94416
# [3]	validation_0-rmse:0.94290
# [4]	validation_0-rmse:0.94171
# [5]	validation_0-rmse:0.94072
# [6]	validation_0-rmse:0.93951
# [7]	validation_0-rmse:0.93832
# [8]	validation_0-rmse:0.93730
# [9]	validation_0-rmse:0.93636
# [10]	validation_0-rmse:0.93583
# [11]	validation_0-rmse:0.93485
# [12]	validation_0-rmse:0.93395
# [13]	validation_0-rmse:0.93310
# [14]	validation_0-rmse:0.93231
# [15]	validation_0-rmse:0.93175
# [16]	validation_0-rmse:0.93112
# [17]	validation_0-rmse:0.93040
# [18]	validation_0-rmse:0.92960
# [19]	validation_0-rmse:0.92893
# [20]	validation_0-rmse:0.92844
# [21]	validation_0-rmse:0.92800
# [22]	validation_0-rmse:0.92732
# [23]	validation_0-rmse:0.92660
# [24]	validation_0-rmse:0.92615
# [25]	validation_0-rmse:0.92519
# [26]	validation_0-rmse:0.92450
# [27]	validation_0-rmse:0.92395
# [28]	validation_0-rmse:0.92351
# [29]	validation_0-rmse:0.92271
# [30]	validation_0-rmse:0.92221
# [31]	validation_0-rmse:0.92202
# [32]	validation_0-rmse:0.92160
# [33]	validation_0-rmse:0.92093
# [34]	validation_0-rmse:0.92076
# [35]	validation_0-rmse:0.92029
# [36]	validation_0-rmse:0.91984
# [37]	validation_0-rmse:0.91955
# [38]	validation_0-rmse:0.91907
# [39]	validation_0-rmse:0.91869
# [40]	validation_0-rmse:0.91802
# [41]	validation_0-rmse:0.91768
# [42]	validation_0-rmse:0.91714
# [43]	validation_0-rmse:0.91682
# [44]	validation_0-rmse:0.91656
# [45]	validation_0-rmse:0.91604
# [46]	validation_0-rmse:0.91572
# [47]	validation_0-rmse:0.91532
# [48]	validation_0-rmse:0.91508
# [49]	validation_0-rmse:0.91490
# [50]	validation_0-rmse:0.91465
# [51]	validation_0-rmse:0.91454
# [52]	validation_0-rmse:0.91396
# [53]	validation_0-rmse:0.91362
# [54]	validation_0-rmse:0.91340
# [55]	validation_0-rmse:0.91304
# [56]	validation_0-rmse:0.91277
# [57]	validation_0-rmse:0.91232
# [58]	validation_0-rmse:0.91221
# [59]	validation_0-rmse:0.91206
# [60]	validation_0-rmse:0.91186
# [61]	validation_0-rmse:0.91181
# [62]	validation_0-rmse:0.91168
# [63]	validation_0-rmse:0.91148
# [64]	validation_0-rmse:0.91128
# [65]	validation_0-rmse:0.91092
# [66]	validation_0-rmse:0.91063
# [67]	validation_0-rmse:0.91047
# [68]	validation_0-rmse:0.91042
# [69]	validation_0-rmse:0.91025
# [70]	validation_0-rmse:0.90976
# [71]	validation_0-rmse:0.90947
# [72]	validation_0-rmse:0.90913
# [73]	validation_0-rmse:0.90918
# [74]	validation_0-rmse:0.90909
# [75]	validation_0-rmse:0.90873
# [76]	validation_0-rmse:0.90855
# [77]	validation_0-rmse:0.90847
# [78]	validation_0-rmse:0.90830
# [79]	validation_0-rmse:0.90816
# [80]	validation_0-rmse:0.90777
# [81]	validation_0-rmse:0.90773
# [82]	validation_0-rmse:0.90764
# [83]	validation_0-rmse:0.90755
# [84]	validation_0-rmse:0.90731
# [85]	validation_0-rmse:0.90722
# [86]	validation_0-rmse:0.90721
# [87]	validation_0-rmse:0.90718
# [88]	validation_0-rmse:0.90697
# [89]	validation_0-rmse:0.90686
# [90]	validation_0-rmse:0.90666
# [91]	validation_0-rmse:0.90658
# [92]	validation_0-rmse:0.90646
# [93]	validation_0-rmse:0.90619
# [94]	validation_0-rmse:0.90598
# [95]	validation_0-rmse:0.90590
# [96]	validation_0-rmse:0.90591
# [97]	validation_0-rmse:0.90586
# [98]	validation_0-rmse:0.90581
# [99]	validation_0-rmse:0.90554
# [100]	validation_0-rmse:0.90555
# [101]	validation_0-rmse:0.90563
# [102]	validation_0-rmse:0.90543
# [103]	validation_0-rmse:0.90538
# [104]	validation_0-rmse:0.90531
# [105]	validation_0-rmse:0.90513
# [106]	validation_0-rmse:0.90523
# [107]	validation_0-rmse:0.90501
# [108]	validation_0-rmse:0.90493
# [109]	validation_0-rmse:0.90486
# [110]	validation_0-rmse:0.90481
# [111]	validation_0-rmse:0.90467
# [112]	validation_0-rmse:0.90475
# [113]	validation_0-rmse:0.90483
# [114]	validation_0-rmse:0.90460
# [115]	validation_0-rmse:0.90453
# [116]	validation_0-rmse:0.90432
# [117]	validation_0-rmse:0.90437
# [118]	validation_0-rmse:0.90432
# [119]	validation_0-rmse:0.90420
# [120]	validation_0-rmse:0.90438
# [121]	validation_0-rmse:0.90425
# [122]	validation_0-rmse:0.90413
# [123]	validation_0-rmse:0.90406
# [124]	validation_0-rmse:0.90401
# [125]	validation_0-rmse:0.90418
# [126]	validation_0-rmse:0.90411
# [127]	validation_0-rmse:0.90402
# [128]	validation_0-rmse:0.90395
# [129]	validation_0-rmse:0.90396
# [130]	validation_0-rmse:0.90377
# [131]	validation_0-rmse:0.90372
# [132]	validation_0-rmse:0.90381
# [133]	validation_0-rmse:0.90386
# [134]	validation_0-rmse:0.90379
# [135]	validation_0-rmse:0.90382
# [136]	validation_0-rmse:0.90369
# [137]	validation_0-rmse:0.90363
# [138]	validation_0-rmse:0.90366
# [139]	validation_0-rmse:0.90358
# [140]	validation_0-rmse:0.90354
# [141]	validation_0-rmse:0.90344
# [142]	validation_0-rmse:0.90346
# [143]	validation_0-rmse:0.90341
# [144]	validation_0-rmse:0.90338
# [145]	validation_0-rmse:0.90328
# [146]	validation_0-rmse:0.90314
# [147]	validation_0-rmse:0.90311
# [148]	validation_0-rmse:0.90301
# [149]	validation_0-rmse:0.90300
# [150]	validation_0-rmse:0.90291
# [151]	validation_0-rmse:0.90273
# [152]	validation_0-rmse:0.90281
# [153]	validation_0-rmse:0.90285
# [154]	validation_0-rmse:0.90271
# [155]	validation_0-rmse:0.90282
# [156]	validation_0-rmse:0.90284
# [157]	validation_0-rmse:0.90278
# [158]	validation_0-rmse:0.90280
# [159]	validation_0-rmse:0.90279
# [160]	validation_0-rmse:0.90280
# [161]	validation_0-rmse:0.90272
# [162]	validation_0-rmse:0.90273
# [163]	validation_0-rmse:0.90268
# [164]	validation_0-rmse:0.90269
# [165]	validation_0-rmse:0.90261
# [166]	validation_0-rmse:0.90251
# [167]	validation_0-rmse:0.90231
# [168]	validation_0-rmse:0.90226
# [169]	validation_0-rmse:0.90238
# [170]	validation_0-rmse:0.90233
# [171]	validation_0-rmse:0.90228
# [172]	validation_0-rmse:0.90242
# [173]	validation_0-rmse:0.90246
# [174]	validation_0-rmse:0.90250
# [175]	validation_0-rmse:0.90249
# [176]	validation_0-rmse:0.90249
# [177]	validation_0-rmse:0.90236
# [178]	validation_0-rmse:0.90251
# [179]	validation_0-rmse:0.90240
# [180]	validation_0-rmse:0.90252
# [181]	validation_0-rmse:0.90257
# [182]	validation_0-rmse:0.90258
# [183]	validation_0-rmse:0.90269
# [184]	validation_0-rmse:0.90269
# [185]	validation_0-rmse:0.90267
# [186]	validation_0-rmse:0.90262
# [187]	validation_0-rmse:0.90253
# [188]	validation_0-rmse:0.90236
# [189]	validation_0-rmse:0.90212
# [190]	validation_0-rmse:0.90208
# [191]	validation_0-rmse:0.90219
# [192]	validation_0-rmse:0.90222
# [193]	validation_0-rmse:0.90222
# [194]	validation_0-rmse:0.90220
# [195]	validation_0-rmse:0.90219
# [196]	validation_0-rmse:0.90224
# [197]	validation_0-rmse:0.90223
# [198]	validation_0-rmse:0.90211
# [199]	validation_0-rmse:0.90218
# [200]	validation_0-rmse:0.90206
# [201]	validation_0-rmse:0.90200
# [202]	validation_0-rmse:0.90195
# [203]	validation_0-rmse:0.90192
# [204]	validation_0-rmse:0.90201
# [205]	validation_0-rmse:0.90206
# [206]	validation_0-rmse:0.90182
# [207]	validation_0-rmse:0.90174
# [208]	validation_0-rmse:0.90168
# [209]	validation_0-rmse:0.90175
# [210]	validation_0-rmse:0.90171
# [211]	validation_0-rmse:0.90171
# [212]	validation_0-rmse:0.90172
# [213]	validation_0-rmse:0.90159
# [214]	validation_0-rmse:0.90151
# [215]	validation_0-rmse:0.90161
# [216]	validation_0-rmse:0.90155
# [217]	validation_0-rmse:0.90157
# [218]	validation_0-rmse:0.90164
# [219]	validation_0-rmse:0.90158
# [220]	validation_0-rmse:0.90150
# [221]	validation_0-rmse:0.90155
# [222]	validation_0-rmse:0.90153
# [223]	validation_0-rmse:0.90156
# [224]	validation_0-rmse:0.90159
# [225]	validation_0-rmse:0.90162
# [226]	validation_0-rmse:0.90154
# [227]	validation_0-rmse:0.90149
# [228]	validation_0-rmse:0.90141
# [229]	validation_0-rmse:0.90139
# [230]	validation_0-rmse:0.90127
# [231]	validation_0-rmse:0.90134
# [232]	validation_0-rmse:0.90128
# [233]	validation_0-rmse:0.90129
# [234]	validation_0-rmse:0.90140
# [235]	validation_0-rmse:0.90157
# [236]	validation_0-rmse:0.90156
# [237]	validation_0-rmse:0.90159
# [238]	validation_0-rmse:0.90159
# [239]	validation_0-rmse:0.90155
# [240]	validation_0-rmse:0.90166
# [241]	validation_0-rmse:0.90170
# [242]	validation_0-rmse:0.90177
# [243]	validation_0-rmse:0.90182
# [244]	validation_0-rmse:0.90182
# [245]	validation_0-rmse:0.90191
# [246]	validation_0-rmse:0.90193
# [247]	validation_0-rmse:0.90188
# [248]	validation_0-rmse:0.90195
# [249]	validation_0-rmse:0.90202
# [250]	validation_0-rmse:0.90179
# [251]	validation_0-rmse:0.90188
# [252]	validation_0-rmse:0.90187
# [253]	validation_0-rmse:0.90192
# [254]	validation_0-rmse:0.90194
# [255]	validation_0-rmse:0.90201
# [256]	validation_0-rmse:0.90214
# [257]	validation_0-rmse:0.90210
# [258]	validation_0-rmse:0.90211
# [259]	validation_0-rmse:0.90205
# [260]	validation_0-rmse:0.90194
# [261]	validation_0-rmse:0.90208
# [262]	validation_0-rmse:0.90206
# [263]	validation_0-rmse:0.90193
# [264]	validation_0-rmse:0.90179
# [265]	validation_0-rmse:0.90185
# [266]	validation_0-rmse:0.90186
# [267]	validation_0-rmse:0.90175
# [268]	validation_0-rmse:0.90182
# [269]	validation_0-rmse:0.90185
# [270]	validation_0-rmse:0.90196
# [271]	validation_0-rmse:0.90189
# [272]	validation_0-rmse:0.90182
# [273]	validation_0-rmse:0.90183
# [274]	validation_0-rmse:0.90195
# [275]	validation_0-rmse:0.90203
# [276]	validation_0-rmse:0.90212
# [277]	validation_0-rmse:0.90213
# [278]	validation_0-rmse:0.90210
# [279]	validation_0-rmse:0.90203
# [280]	validation_0-rmse:0.90203
# [281]	validation_0-rmse:0.90207
# [282]	validation_0-rmse:0.90207
# [283]	validation_0-rmse:0.90216
# [284]	validation_0-rmse:0.90219
# [285]	validation_0-rmse:0.90215
# [286]	validation_0-rmse:0.90211
# [287]	validation_0-rmse:0.90220
# [288]	validation_0-rmse:0.90220
# [289]	validation_0-rmse:0.90226
# [290]	validation_0-rmse:0.90230
# [291]	validation_0-rmse:0.90236
# [292]	validation_0-rmse:0.90243
# [293]	validation_0-rmse:0.90247
# [294]	validation_0-rmse:0.90242
# [295]	validation_0-rmse:0.90245
# [296]	validation_0-rmse:0.90268
# [297]	validation_0-rmse:0.90270
# [298]	validation_0-rmse:0.90276
# [299]	validation_0-rmse:0.90278
# [300]	validation_0-rmse:0.90293
# [301]	validation_0-rmse:0.90299
# [302]	validation_0-rmse:0.90308
# [303]	validation_0-rmse:0.90324
# [304]	validation_0-rmse:0.90321
# [305]	validation_0-rmse:0.90326
# [306]	validation_0-rmse:0.90335
# [307]	validation_0-rmse:0.90329
# [308]	validation_0-rmse:0.90328
# [309]	validation_0-rmse:0.90330
# [310]	validation_0-rmse:0.90335
# [311]	validation_0-rmse:0.90343
# [312]	validation_0-rmse:0.90338
# [313]	validation_0-rmse:0.90334
# [314]	validation_0-rmse:0.90337
# [315]	validation_0-rmse:0.90332
# [316]	validation_0-rmse:0.90329
# [317]	validation_0-rmse:0.90329
# [318]	validation_0-rmse:0.90333
# [319]	validation_0-rmse:0.90325
# [320]	validation_0-rmse:0.90321
# [321]	validation_0-rmse:0.90326
# [322]	validation_0-rmse:0.90321
# [323]	validation_0-rmse:0.90328
# [324]	validation_0-rmse:0.90340
# [325]	validation_0-rmse:0.90326
# [326]	validation_0-rmse:0.90333
# [327]	validation_0-rmse:0.90329
# [328]	validation_0-rmse:0.90319
# [329]	validation_0-rmse:0.90312
# [330]	validation_0-rmse:0.90309
# [331]	validation_0-rmse:0.90313
# [332]	validation_0-rmse:0.90313
# [333]	validation_0-rmse:0.90321
# [334]	validation_0-rmse:0.90319
# [335]	validation_0-rmse:0.90329
# [336]	validation_0-rmse:0.90334
# [337]	validation_0-rmse:0.90348
# [338]	validation_0-rmse:0.90360
# [339]	validation_0-rmse:0.90357
# [340]	validation_0-rmse:0.90358
# [341]	validation_0-rmse:0.90360
# [342]	validation_0-rmse:0.90372
# [343]	validation_0-rmse:0.90378
# [344]	validation_0-rmse:0.90386
# [345]	validation_0-rmse:0.90389
# [346]	validation_0-rmse:0.90400
# [347]	validation_0-rmse:0.90416
# [348]	validation_0-rmse:0.90432
# [349]	validation_0-rmse:0.90430
# [350]	validation_0-rmse:0.90439
# [351]	validation_0-rmse:0.90436
# [352]	validation_0-rmse:0.90444
# [353]	validation_0-rmse:0.90446
# [354]	validation_0-rmse:0.90452
# [355]	validation_0-rmse:0.90445
# [356]	validation_0-rmse:0.90453
# [357]	validation_0-rmse:0.90450
# [358]	validation_0-rmse:0.90457
# [359]	validation_0-rmse:0.90463
# [360]	validation_0-rmse:0.90461
# [361]	validation_0-rmse:0.90459
# [362]	validation_0-rmse:0.90458
# [363]	validation_0-rmse:0.90458
# [364]	validation_0-rmse:0.90477
# [365]	validation_0-rmse:0.90472
# [366]	validation_0-rmse:0.90469
# [367]	validation_0-rmse:0.90472
# [368]	validation_0-rmse:0.90475
# [369]	validation_0-rmse:0.90475
# [370]	validation_0-rmse:0.90471
# [371]	validation_0-rmse:0.90473
# [372]	validation_0-rmse:0.90475
# [373]	validation_0-rmse:0.90482
# [374]	validation_0-rmse:0.90477
# [375]	validation_0-rmse:0.90478
# [376]	validation_0-rmse:0.90476
# [377]	validation_0-rmse:0.90474
# [378]	validation_0-rmse:0.90474
# [379]	validation_0-rmse:0.90485
# [380]	validation_0-rmse:0.90497
# [381]	validation_0-rmse:0.90506
# [382]	validation_0-rmse:0.90508
# [383]	validation_0-rmse:0.90506
# [384]	validation_0-rmse:0.90502
# [385]	validation_0-rmse:0.90508
# [386]	validation_0-rmse:0.90515
# [387]	validation_0-rmse:0.90522
# [388]	validation_0-rmse:0.90525
# [389]	validation_0-rmse:0.90513
# [390]	validation_0-rmse:0.90522
# [391]	validation_0-rmse:0.90515
# [392]	validation_0-rmse:0.90525
# [393]	validation_0-rmse:0.90522
# [394]	validation_0-rmse:0.90524
# [395]	validation_0-rmse:0.90525
# [396]	validation_0-rmse:0.90532
# [397]	validation_0-rmse:0.90521
# test MSE: 0.8193991184234619
# test MAE: 0.6946278810501099

# %%
import numpy as np
import random

def hit_rate_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    hits = len(set(predicted_at_k) & set(true_items))
    return 1.0 if hits > 0 else 0.0

def ndcg_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    dcg = 0.0
    idcg = sum((1.0 / np.log2(i + 2) for i in range(min(len(true_items), k))))
    
    for i, item in enumerate(predicted_at_k):
        if item in true_items:
            dcg += 1.0 / np.log2(i + 2)  # Log base 2

    return dcg / idcg if idcg > 0 else 0.0

hr_values = []
ndcg_values = []
hr_seren_values = []
ndcg_seren_values = []
rating_threshold = 3
serendipity_items = 0
serendipity_survival_items = 0
all_item_ids = set(all_item_ids)
number_negative_examples = 20
for k in [5,10]:
    for user_id in test_data['user_id'].unique():
        user_test_items = test_data[test_data['user_id'] == user_id]
        positive_items = user_test_items[user_test_items['rating'] > rating_threshold]['item_id'].tolist()
        if not positive_items:
            continue


        for target_item in positive_items:

            negative_items = user_test_items[user_test_items['rating'] <= rating_threshold]['item_id'].tolist()
            random.shuffle(negative_items)
            candidate_items = [target_item] + negative_items[:20]  # Limitar a 99 negativos
            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                 serendipity_items += 1
            if not len(candidate_items) >  number_negative_examples:
                interacted_items = set(data[data['user_id'] == user_id]['item_id'])
                non_interacted_items = all_item_ids - interacted_items
                filtered_items = data[data['item_id'].isin(non_interacted_items)]['item_id'].unique()
                num_items_to_select = number_negative_examples - len(candidate_items) + 1
                random_items = random.sample(list(filtered_items), num_items_to_select)
                candidate_items = candidate_items + random_items
            
            X_user = []
            items_id_list = []
            for item_id in candidate_items:
                user_idx = train_user_id_map.get(user_id)
                item_idx = train_item_id_map.get(item_id)
                user_embedding = user_embeddings[user_idx]if user_idx is not None else default_user_embedding
                item_embedding = item_embeddings_mf[item_idx] if item_idx is not None else default_item_embedding_svd
                item_embedding_bert = item_embeddings_dict[item_id]
                item_final = np.hstack((item_embedding_bert, item_embedding))
                
                #calculate serendipity using the serendipity classifier
                #consider in tests as if the real-world example would calculate it in order to integrate new interactions in the system
                serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
                serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
                serendipity_class = (serendipit_pred >= 0.5).astype(int)
                
                serendipity_weight = 3.0 if serendipity_class == 1 else 1.0
                item_final = item_final * serendipity_weight
            
                serendipity_feature = np.array([1]) if serendipity_class == 1 else np.array([0])
                
                combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
                X_user.append(combined_embedding)
                items_id_list.append(item_id)
        
            X_user = np.array(X_user)
            y_score = xgb_model.predict(X_user)
        
            predicted_ratings = pd.DataFrame({
                'item_id': candidate_items,
                'predicted_rating': y_score
            })
        
            predicted_ratings = predicted_ratings.sort_values(by='predicted_rating', ascending=False)
            ordered_items = predicted_ratings['item_id'].tolist()
            hr = hit_rate_at_k(ordered_items, [target_item], k)
            ndcg = ndcg_at_k(ordered_items, [target_item], k)
            hr_values.append(hr)
            ndcg_values.append(ndcg)

            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                serendipity_survival_items += 1
                hr = hit_rate_at_k(ordered_items, [target_item], k)
                ndcg = ndcg_at_k(ordered_items, [target_item], k)
                hr_seren_values.append(hr)
                ndcg_seren_values.append(ndcg)

        
    average_hr = np.mean(hr_values)
    average_ndcg = np.mean(ndcg_values)
    average_hr_seren = np.mean(hr_seren_values)
    average_ndcg_seren = np.mean(ndcg_seren_values)
    
    print(f"Average HR@{k}: {average_hr}")
    print(f"Average NDCG@{k}: {average_ndcg}")
    print(f"Average HR_seren@{k}: {average_hr_seren}")
    print(f"Average NDCG_seren@{k}: {average_ndcg_seren}")
# Out:
# Average HR@5: 0.22741116751269036
# Average NDCG@5: 0.13530441708772678
# Average HR_seren@5: 0.31521739130434784
# Average NDCG_seren@5: 0.18659232826136335
# Average HR@10: 0.3565989847715736
# Average NDCG@10: 0.1774284795431178
# Average HR_seren@10: 0.40217391304347827
# Average NDCG_seren@10: 0.21044082004125267
