# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from sklearn.metrics import precision_score, recall_score, accuracy_score, mean_squared_error, mean_absolute_error
import optuna
import xgboost as xgb
import numpy as np

train_data = pd.read_csv('../train_data.csv', dtype={'item_id': str}, sep=';')
test_data = pd.read_csv('../test_data.csv', dtype={'item_id': str}, sep=';')
data = pd.read_csv('../Data/serenlens_with_features_cleaned_filtered.csv', dtype={'item_id': str}, sep=";")
all_item_ids = data['item_id'].unique()

# load serendipity classifier model
predict_serendipity = xgb.XGBClassifier()
predict_serendipity.load_model('../serendipity_classifier/serendipity_classifier_distilroberta.json')

def load_embeddings(embedding_path, item_ids):
    embeddings = np.load(embedding_path)
    return {item_id: normalize(embedding.reshape(1, -1)).flatten() for item_id, embedding in zip(item_ids, embeddings)}

train_user_ids = train_data['user_id'].unique()
train_item_ids = train_data['item_id'].unique()
train_user_id_map = {user_id: idx for idx, user_id in enumerate(train_user_ids)}
train_item_id_map = {item_id: idx for idx, item_id in enumerate(train_item_ids)}

interaction_matrix = train_data.pivot(index='user_id', columns='item_id', values='rating').fillna(0)
svd = TruncatedSVD(n_components=50, random_state=42)
user_embeddings = svd.fit_transform(interaction_matrix)
item_embeddings_mf = svd.components_.T

scaler = StandardScaler()
user_embeddings = scaler.fit_transform(user_embeddings)
item_embeddings_mf = scaler.fit_transform(item_embeddings_mf)

# description embeddings
item_embeddings_dict = load_embeddings('../embeddings/distilroberta_embeddings.npy', all_item_ids)

# default embedding for missing embeddings in test
default_user_embedding = np.mean(user_embeddings, axis=0)
default_item_embedding_svd = np.mean(item_embeddings_mf, axis=0)

default_user_embedding = normalize(default_user_embedding.reshape(1, -1)).flatten()
default_item_embedding_svd = normalize(default_item_embedding_svd.reshape(1, -1)).flatten()

def generate_embeddings(data, data_samples):
    combined_embedding = []
    for idx, row in data.iterrows():
        user_idx = train_user_id_map.get(row['user_id'])
        item_idx = train_item_id_map.get(row['item_id'])
        user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
        item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
        item_embedding_bert = item_embeddings_dict[row['item_id']]
        item_final = np.hstack((item_embedding_bert, item_embedding))
    
        #calculate serendipity using the serendipity classifier
        serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
        serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
        
        # favour serenpity interactions
        serendipity_weight = 1 + serendipit_pred
        item_final = item_final * serendipity_weight
    
        # add serendipity as a feature
        serendipity_feature = np.array([serendipit_pred]).reshape(1, -1).flatten()
        
        combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
        data_samples.append((combined_embedding, row['rating']))

train_data_samples = []
generate_embeddings(train_data, train_data_samples)

X_train, y_train = zip(*train_data_samples)
X_train = np.array(X_train)
y_train = np.array(y_train)

test_data_samples = []
generate_embeddings(test_data, test_data_samples)

X_test, y_test = zip(*test_data_samples)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

def objective(trial):
    param = {
        'objective': 'reg:squarederror',
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
    }
    
    xgb_model = xgb.XGBRegressor(**param)
    
    X_train_opt, X_valid_opt, y_train_opt, y_valid_opt = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    
    xgb_model.fit(X_train_opt, y_train_opt, eval_set=[(X_valid_opt, y_valid_opt)], verbose=False)
    
    y_pred = xgb_model.predict(X_valid_opt)
    
    mse = mean_squared_error(y_valid_opt, y_pred)
    
    # minimize mse    
    return mse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print("best hyperparameters found:")
print(study.best_params)

# use best hyperparameters
best_params = study.best_params
xgb_model = xgb.XGBRegressor(**best_params)
xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=True)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'test MSE: {mse}')
print(f'test MAE: {mae}')
# Out:
# [I 2024-09-21 15:37:03,422] A new study created in memory with name: no-name-3a8d0759-7a4a-4669-91f2-94ad660cdab5
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:37:11,301] Trial 0 finished with value: 0.8577408790588379 and parameters: {'n_estimators': 437, 'max_depth': 4, 'learning_rate': 0.20146151290531636, 'subsample': 0.9170258616198509, 'colsample_bytree': 0.7921826010490718, 'reg_alpha': 0.1316397548618676, 'reg_lambda': 0.19193377773727352}. Best is trial 0 with value: 0.8577408790588379.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:37:34,577] Trial 1 finished with value: 0.7762068510055542 and parameters: {'n_estimators': 275, 'max_depth': 8, 'learning_rate': 0.012447397682950145, 'subsample': 0.7504654794255647, 'colsample_bytree': 0.6447862307930573, 'reg_alpha': 6.987618276561302, 'reg_lambda': 9.708388955763683}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:37:40,967] Trial 2 finished with value: 0.7834574580192566 and parameters: {'n_estimators': 495, 'max_depth': 3, 'learning_rate': 0.06633558428753647, 'subsample': 0.8979306255611417, 'colsample_bytree': 0.6076319791712756, 'reg_alpha': 0.14301688567183862, 'reg_lambda': 0.6768789703651285}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:37:47,460] Trial 3 finished with value: 0.779369056224823 and parameters: {'n_estimators': 471, 'max_depth': 3, 'learning_rate': 0.06759774445505959, 'subsample': 0.8237837137749033, 'colsample_bytree': 0.7850306184803952, 'reg_alpha': 0.2887532286024711, 'reg_lambda': 1.965452505041868}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:38:19,712] Trial 4 finished with value: 0.7832663059234619 and parameters: {'n_estimators': 365, 'max_depth': 8, 'learning_rate': 0.03365005592790156, 'subsample': 0.7663175879070298, 'colsample_bytree': 0.8283745614574773, 'reg_alpha': 5.802192493935031, 'reg_lambda': 0.38087043703925744}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:38:33,411] Trial 5 finished with value: 0.837665319442749 and parameters: {'n_estimators': 332, 'max_depth': 6, 'learning_rate': 0.17199559060110478, 'subsample': 0.9215271570432269, 'colsample_bytree': 0.7933345943576555, 'reg_alpha': 0.44907080559771084, 'reg_lambda': 0.7002109331586653}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:38:36,477] Trial 6 finished with value: 0.8176335096359253 and parameters: {'n_estimators': 209, 'max_depth': 3, 'learning_rate': 0.2414385268052243, 'subsample': 0.9801413925667384, 'colsample_bytree': 0.6761756315492882, 'reg_alpha': 6.802578091667583, 'reg_lambda': 1.7336170335239258}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:38:49,474] Trial 7 finished with value: 0.845787525177002 and parameters: {'n_estimators': 131, 'max_depth': 8, 'learning_rate': 0.2307740120122864, 'subsample': 0.9960297489474239, 'colsample_bytree': 0.7495320946661881, 'reg_alpha': 0.2386743447883113, 'reg_lambda': 0.2645260991972319}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:39:06,753] Trial 8 finished with value: 0.8877357840538025 and parameters: {'n_estimators': 290, 'max_depth': 7, 'learning_rate': 0.23180704328380158, 'subsample': 0.9166122623597968, 'colsample_bytree': 0.7060045971097592, 'reg_alpha': 0.4430352048275399, 'reg_lambda': 0.12890065388351565}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:39:17,727] Trial 9 finished with value: 0.9022219777107239 and parameters: {'n_estimators': 393, 'max_depth': 5, 'learning_rate': 0.299921975859836, 'subsample': 0.9439999739554614, 'colsample_bytree': 0.8447051482571106, 'reg_alpha': 0.3010635754612616, 'reg_lambda': 9.00245633683764}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:40:06,011] Trial 10 finished with value: 0.7789669036865234 and parameters: {'n_estimators': 248, 'max_depth': 10, 'learning_rate': 0.01054608651606572, 'subsample': 0.6308689894869851, 'colsample_bytree': 0.9636301451169954, 'reg_alpha': 2.209243129197227, 'reg_lambda': 8.603637066444602}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:40:55,808] Trial 11 finished with value: 0.7804113626480103 and parameters: {'n_estimators': 250, 'max_depth': 10, 'learning_rate': 0.01016092486349147, 'subsample': 0.6391541720606266, 'colsample_bytree': 0.998936118592444, 'reg_alpha': 2.65473786196008, 'reg_lambda': 9.803673652329092}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:41:29,621] Trial 12 finished with value: 0.7841274738311768 and parameters: {'n_estimators': 175, 'max_depth': 10, 'learning_rate': 0.010304063695409814, 'subsample': 0.634757889364457, 'colsample_bytree': 0.9329639746294944, 'reg_alpha': 1.8923822131137742, 'reg_lambda': 3.2758563415569513}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:42:08,817] Trial 13 finished with value: 0.7806539535522461 and parameters: {'n_estimators': 278, 'max_depth': 9, 'learning_rate': 0.02030266740135709, 'subsample': 0.6950005899681914, 'colsample_bytree': 0.8890094640715573, 'reg_alpha': 3.004133324213154, 'reg_lambda': 4.755675340517515}. Best is trial 1 with value: 0.7762068510055542.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:42:37,029] Trial 14 finished with value: 0.7753516435623169 and parameters: {'n_estimators': 224, 'max_depth': 9, 'learning_rate': 0.018591220773852838, 'subsample': 0.7273361362430603, 'colsample_bytree': 0.606149062453068, 'reg_alpha': 0.9868406333477785, 'reg_lambda': 4.712702857543667}. Best is trial 14 with value: 0.7753516435623169.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:42:53,117] Trial 15 finished with value: 0.7742624282836914 and parameters: {'n_estimators': 180, 'max_depth': 8, 'learning_rate': 0.02005575465957488, 'subsample': 0.7587357902783389, 'colsample_bytree': 0.6310793203815288, 'reg_alpha': 0.7685627464853609, 'reg_lambda': 3.9068182452142053}. Best is trial 15 with value: 0.7742624282836914.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:43:00,267] Trial 16 finished with value: 0.7770663499832153 and parameters: {'n_estimators': 122, 'max_depth': 7, 'learning_rate': 0.031336729507461025, 'subsample': 0.8211623228828197, 'colsample_bytree': 0.6075138436086988, 'reg_alpha': 0.9477496191068725, 'reg_lambda': 3.9792879289251446}. Best is trial 15 with value: 0.7742624282836914.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:43:16,974] Trial 17 finished with value: 0.76905357837677 and parameters: {'n_estimators': 191, 'max_depth': 8, 'learning_rate': 0.019375111022271158, 'subsample': 0.7109593487317751, 'colsample_bytree': 0.7183926674706883, 'reg_alpha': 0.9529046846235963, 'reg_lambda': 1.6751697973222266}. Best is trial 17 with value: 0.76905357837677.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:43:23,947] Trial 18 finished with value: 0.7778090834617615 and parameters: {'n_estimators': 172, 'max_depth': 6, 'learning_rate': 0.03028640168453878, 'subsample': 0.6840258922675961, 'colsample_bytree': 0.7257816397993353, 'reg_alpha': 0.6610034059967985, 'reg_lambda': 1.5213728751709108}. Best is trial 17 with value: 0.76905357837677.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:43:39,382] Trial 19 finished with value: 0.8114455342292786 and parameters: {'n_estimators': 104, 'max_depth': 9, 'learning_rate': 0.102971972166213, 'subsample': 0.8579653358323364, 'colsample_bytree': 0.6737251300087309, 'reg_alpha': 1.5195476962867274, 'reg_lambda': 1.0201636102390597}. Best is trial 17 with value: 0.76905357837677.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:43:48,856] Trial 20 finished with value: 0.7773734927177429 and parameters: {'n_estimators': 158, 'max_depth': 7, 'learning_rate': 0.01792794376437694, 'subsample': 0.7825465155669904, 'colsample_bytree': 0.6584931020849131, 'reg_alpha': 0.703084625891447, 'reg_lambda': 2.9263311041189146}. Best is trial 17 with value: 0.76905357837677.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:44:17,627] Trial 21 finished with value: 0.7736104726791382 and parameters: {'n_estimators': 213, 'max_depth': 9, 'learning_rate': 0.02002402597394584, 'subsample': 0.7143892512524035, 'colsample_bytree': 0.6294407303829079, 'reg_alpha': 1.5097570999633472, 'reg_lambda': 5.84172063308307}. Best is trial 17 with value: 0.76905357837677.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:44:36,074] Trial 22 finished with value: 0.775111734867096 and parameters: {'n_estimators': 201, 'max_depth': 8, 'learning_rate': 0.022383065261152583, 'subsample': 0.6966551699286226, 'colsample_bytree': 0.7031593103202953, 'reg_alpha': 1.2716165175947367, 'reg_lambda': 5.402133848470557}. Best is trial 17 with value: 0.76905357837677.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# ...
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:53:10,521] Trial 46 finished with value: 0.7708909511566162 and parameters: {'n_estimators': 445, 'max_depth': 7, 'learning_rate': 0.011374078992039321, 'subsample': 0.6896566040233936, 'colsample_bytree': 0.6418689931937059, 'reg_alpha': 1.6854579225303679, 'reg_lambda': 0.10347964483805648}. Best is trial 41 with value: 0.7688462734222412.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:53:37,218] Trial 47 finished with value: 0.7711418867111206 and parameters: {'n_estimators': 451, 'max_depth': 7, 'learning_rate': 0.012771637663619951, 'subsample': 0.6872872123459173, 'colsample_bytree': 0.6490404094093528, 'reg_alpha': 1.732115028170114, 'reg_lambda': 0.6855213242568834}. Best is trial 41 with value: 0.7688462734222412.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:54:04,970] Trial 48 finished with value: 0.7688851356506348 and parameters: {'n_estimators': 473, 'max_depth': 7, 'learning_rate': 0.011762986187223289, 'subsample': 0.689666530078865, 'colsample_bytree': 0.6222114328198315, 'reg_alpha': 1.8425287143066287, 'reg_lambda': 0.12568409878572423}. Best is trial 41 with value: 0.7688462734222412.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:103: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:104: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_12260\1499137526.py:105: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 15:54:32,424] Trial 49 finished with value: 0.7745936512947083 and parameters: {'n_estimators': 467, 'max_depth': 7, 'learning_rate': 0.01177966923478759, 'subsample': 0.6845455957061424, 'colsample_bytree': 0.6017085434040632, 'reg_alpha': 2.31012320228158, 'reg_lambda': 0.11587502164098233}. Best is trial 41 with value: 0.7688462734222412.
# best hyperparameters found:
# {'n_estimators': 265, 'max_depth': 8, 'learning_rate': 0.017639753190205495, 'subsample': 0.7650710792179155, 'colsample_bytree': 0.6681872652881437, 'reg_alpha': 0.577931385519385, 'reg_lambda': 0.38265637592519464}
# [0]	validation_0-rmse:0.94706
# [1]	validation_0-rmse:0.94601
# [2]	validation_0-rmse:0.94505
# [3]	validation_0-rmse:0.94383
# [4]	validation_0-rmse:0.94273
# [5]	validation_0-rmse:0.94180
# [6]	validation_0-rmse:0.94123
# [7]	validation_0-rmse:0.93998
# [8]	validation_0-rmse:0.93907
# [9]	validation_0-rmse:0.93805
# [10]	validation_0-rmse:0.93695
# [11]	validation_0-rmse:0.93656
# [12]	validation_0-rmse:0.93585
# [13]	validation_0-rmse:0.93514
# [14]	validation_0-rmse:0.93400
# [15]	validation_0-rmse:0.93289
# [16]	validation_0-rmse:0.93208
# [17]	validation_0-rmse:0.93097
# [18]	validation_0-rmse:0.93007
# [19]	validation_0-rmse:0.92931
# [20]	validation_0-rmse:0.92875
# [21]	validation_0-rmse:0.92805
# [22]	validation_0-rmse:0.92726
# [23]	validation_0-rmse:0.92675
# [24]	validation_0-rmse:0.92613
# [25]	validation_0-rmse:0.92562
# [26]	validation_0-rmse:0.92488
# [27]	validation_0-rmse:0.92443
# [28]	validation_0-rmse:0.92385
# [29]	validation_0-rmse:0.92319
# [30]	validation_0-rmse:0.92277
# [31]	validation_0-rmse:0.92238
# [32]	validation_0-rmse:0.92194
# [33]	validation_0-rmse:0.92143
# [34]	validation_0-rmse:0.92123
# [35]	validation_0-rmse:0.92064
# [36]	validation_0-rmse:0.91975
# [37]	validation_0-rmse:0.91941
# [38]	validation_0-rmse:0.91929
# [39]	validation_0-rmse:0.91889
# [40]	validation_0-rmse:0.91800
# [41]	validation_0-rmse:0.91776
# [42]	validation_0-rmse:0.91713
# [43]	validation_0-rmse:0.91688
# [44]	validation_0-rmse:0.91664
# [45]	validation_0-rmse:0.91639
# [46]	validation_0-rmse:0.91635
# [47]	validation_0-rmse:0.91619
# [48]	validation_0-rmse:0.91596
# [49]	validation_0-rmse:0.91546
# [50]	validation_0-rmse:0.91481
# [51]	validation_0-rmse:0.91483
# [52]	validation_0-rmse:0.91464
# [53]	validation_0-rmse:0.91430
# [54]	validation_0-rmse:0.91384
# [55]	validation_0-rmse:0.91359
# [56]	validation_0-rmse:0.91353
# [57]	validation_0-rmse:0.91319
# [58]	validation_0-rmse:0.91313
# [59]	validation_0-rmse:0.91288
# [60]	validation_0-rmse:0.91263
# [61]	validation_0-rmse:0.91250
# [62]	validation_0-rmse:0.91226
# [63]	validation_0-rmse:0.91229
# [64]	validation_0-rmse:0.91182
# [65]	validation_0-rmse:0.91143
# [66]	validation_0-rmse:0.91103
# [67]	validation_0-rmse:0.91074
# [68]	validation_0-rmse:0.91047
# [69]	validation_0-rmse:0.91012
# [70]	validation_0-rmse:0.90986
# [71]	validation_0-rmse:0.90946
# [72]	validation_0-rmse:0.90904
# [73]	validation_0-rmse:0.90871
# [74]	validation_0-rmse:0.90864
# [75]	validation_0-rmse:0.90872
# [76]	validation_0-rmse:0.90858
# [77]	validation_0-rmse:0.90861
# [78]	validation_0-rmse:0.90848
# [79]	validation_0-rmse:0.90821
# [80]	validation_0-rmse:0.90800
# [81]	validation_0-rmse:0.90774
# [82]	validation_0-rmse:0.90755
# [83]	validation_0-rmse:0.90774
# [84]	validation_0-rmse:0.90750
# [85]	validation_0-rmse:0.90740
# [86]	validation_0-rmse:0.90733
# [87]	validation_0-rmse:0.90721
# [88]	validation_0-rmse:0.90711
# [89]	validation_0-rmse:0.90705
# [90]	validation_0-rmse:0.90702
# [91]	validation_0-rmse:0.90669
# [92]	validation_0-rmse:0.90670
# [93]	validation_0-rmse:0.90649
# [94]	validation_0-rmse:0.90648
# [95]	validation_0-rmse:0.90668
# [96]	validation_0-rmse:0.90665
# [97]	validation_0-rmse:0.90643
# [98]	validation_0-rmse:0.90620
# [99]	validation_0-rmse:0.90600
# [100]	validation_0-rmse:0.90583
# [101]	validation_0-rmse:0.90568
# [102]	validation_0-rmse:0.90576
# [103]	validation_0-rmse:0.90562
# [104]	validation_0-rmse:0.90539
# [105]	validation_0-rmse:0.90546
# [106]	validation_0-rmse:0.90544
# [107]	validation_0-rmse:0.90527
# [108]	validation_0-rmse:0.90497
# [109]	validation_0-rmse:0.90487
# [110]	validation_0-rmse:0.90477
# [111]	validation_0-rmse:0.90491
# [112]	validation_0-rmse:0.90501
# [113]	validation_0-rmse:0.90506
# [114]	validation_0-rmse:0.90486
# [115]	validation_0-rmse:0.90482
# [116]	validation_0-rmse:0.90477
# [117]	validation_0-rmse:0.90464
# [118]	validation_0-rmse:0.90451
# [119]	validation_0-rmse:0.90434
# [120]	validation_0-rmse:0.90446
# [121]	validation_0-rmse:0.90448
# [122]	validation_0-rmse:0.90438
# [123]	validation_0-rmse:0.90420
# [124]	validation_0-rmse:0.90415
# [125]	validation_0-rmse:0.90405
# [126]	validation_0-rmse:0.90401
# [127]	validation_0-rmse:0.90400
# [128]	validation_0-rmse:0.90403
# [129]	validation_0-rmse:0.90393
# [130]	validation_0-rmse:0.90402
# [131]	validation_0-rmse:0.90395
# [132]	validation_0-rmse:0.90384
# [133]	validation_0-rmse:0.90360
# [134]	validation_0-rmse:0.90359
# [135]	validation_0-rmse:0.90358
# [136]	validation_0-rmse:0.90354
# [137]	validation_0-rmse:0.90356
# [138]	validation_0-rmse:0.90339
# [139]	validation_0-rmse:0.90338
# [140]	validation_0-rmse:0.90329
# [141]	validation_0-rmse:0.90320
# [142]	validation_0-rmse:0.90293
# [143]	validation_0-rmse:0.90268
# [144]	validation_0-rmse:0.90267
# [145]	validation_0-rmse:0.90263
# [146]	validation_0-rmse:0.90245
# [147]	validation_0-rmse:0.90235
# [148]	validation_0-rmse:0.90228
# [149]	validation_0-rmse:0.90216
# [150]	validation_0-rmse:0.90215
# [151]	validation_0-rmse:0.90218
# [152]	validation_0-rmse:0.90207
# [153]	validation_0-rmse:0.90206
# [154]	validation_0-rmse:0.90208
# [155]	validation_0-rmse:0.90201
# [156]	validation_0-rmse:0.90203
# [157]	validation_0-rmse:0.90183
# [158]	validation_0-rmse:0.90194
# [159]	validation_0-rmse:0.90197
# [160]	validation_0-rmse:0.90207
# [161]	validation_0-rmse:0.90204
# [162]	validation_0-rmse:0.90204
# [163]	validation_0-rmse:0.90205
# [164]	validation_0-rmse:0.90202
# [165]	validation_0-rmse:0.90209
# [166]	validation_0-rmse:0.90206
# [167]	validation_0-rmse:0.90208
# [168]	validation_0-rmse:0.90212
# [169]	validation_0-rmse:0.90218
# [170]	validation_0-rmse:0.90201
# [171]	validation_0-rmse:0.90209
# [172]	validation_0-rmse:0.90205
# [173]	validation_0-rmse:0.90213
# [174]	validation_0-rmse:0.90200
# [175]	validation_0-rmse:0.90191
# [176]	validation_0-rmse:0.90185
# [177]	validation_0-rmse:0.90185
# [178]	validation_0-rmse:0.90183
# [179]	validation_0-rmse:0.90164
# [180]	validation_0-rmse:0.90170
# [181]	validation_0-rmse:0.90159
# [182]	validation_0-rmse:0.90159
# [183]	validation_0-rmse:0.90164
# [184]	validation_0-rmse:0.90155
# [185]	validation_0-rmse:0.90152
# [186]	validation_0-rmse:0.90146
# [187]	validation_0-rmse:0.90145
# [188]	validation_0-rmse:0.90147
# [189]	validation_0-rmse:0.90157
# [190]	validation_0-rmse:0.90160
# [191]	validation_0-rmse:0.90158
# [192]	validation_0-rmse:0.90154
# [193]	validation_0-rmse:0.90164
# [194]	validation_0-rmse:0.90160
# [195]	validation_0-rmse:0.90157
# [196]	validation_0-rmse:0.90150
# [197]	validation_0-rmse:0.90160
# [198]	validation_0-rmse:0.90162
# [199]	validation_0-rmse:0.90166
# [200]	validation_0-rmse:0.90157
# [201]	validation_0-rmse:0.90154
# [202]	validation_0-rmse:0.90149
# [203]	validation_0-rmse:0.90144
# [204]	validation_0-rmse:0.90162
# [205]	validation_0-rmse:0.90157
# [206]	validation_0-rmse:0.90153
# [207]	validation_0-rmse:0.90143
# [208]	validation_0-rmse:0.90156
# [209]	validation_0-rmse:0.90165
# [210]	validation_0-rmse:0.90158
# [211]	validation_0-rmse:0.90152
# [212]	validation_0-rmse:0.90156
# [213]	validation_0-rmse:0.90156
# [214]	validation_0-rmse:0.90148
# [215]	validation_0-rmse:0.90142
# [216]	validation_0-rmse:0.90148
# [217]	validation_0-rmse:0.90144
# [218]	validation_0-rmse:0.90144
# [219]	validation_0-rmse:0.90145
# [220]	validation_0-rmse:0.90138
# [221]	validation_0-rmse:0.90149
# [222]	validation_0-rmse:0.90147
# [223]	validation_0-rmse:0.90141
# [224]	validation_0-rmse:0.90140
# [225]	validation_0-rmse:0.90147
# [226]	validation_0-rmse:0.90124
# [227]	validation_0-rmse:0.90123
# [228]	validation_0-rmse:0.90128
# [229]	validation_0-rmse:0.90131
# [230]	validation_0-rmse:0.90134
# [231]	validation_0-rmse:0.90159
# [232]	validation_0-rmse:0.90138
# [233]	validation_0-rmse:0.90140
# [234]	validation_0-rmse:0.90126
# [235]	validation_0-rmse:0.90120
# [236]	validation_0-rmse:0.90117
# [237]	validation_0-rmse:0.90130
# [238]	validation_0-rmse:0.90131
# [239]	validation_0-rmse:0.90130
# [240]	validation_0-rmse:0.90131
# [241]	validation_0-rmse:0.90119
# [242]	validation_0-rmse:0.90107
# [243]	validation_0-rmse:0.90129
# [244]	validation_0-rmse:0.90141
# [245]	validation_0-rmse:0.90141
# [246]	validation_0-rmse:0.90143
# [247]	validation_0-rmse:0.90131
# [248]	validation_0-rmse:0.90135
# [249]	validation_0-rmse:0.90135
# [250]	validation_0-rmse:0.90143
# [251]	validation_0-rmse:0.90146
# [252]	validation_0-rmse:0.90146
# [253]	validation_0-rmse:0.90139
# [254]	validation_0-rmse:0.90142
# [255]	validation_0-rmse:0.90152
# [256]	validation_0-rmse:0.90153
# [257]	validation_0-rmse:0.90154
# [258]	validation_0-rmse:0.90151
# [259]	validation_0-rmse:0.90151
# [260]	validation_0-rmse:0.90147
# [261]	validation_0-rmse:0.90158
# [262]	validation_0-rmse:0.90168
# [263]	validation_0-rmse:0.90183
# [264]	validation_0-rmse:0.90178
# test MSE: 0.8132055401802063
# test MAE: 0.6940443515777588

# %%
import numpy as np
import random

def hit_rate_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    hits = len(set(predicted_at_k) & set(true_items))
    return 1.0 if hits > 0 else 0.0

def ndcg_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    dcg = 0.0
    idcg = sum((1.0 / np.log2(i + 2) for i in range(min(len(true_items), k))))
    
    for i, item in enumerate(predicted_at_k):
        if item in true_items:
            dcg += 1.0 / np.log2(i + 2)  # Log base 2

    return dcg / idcg if idcg > 0 else 0.0

hr_values = []
ndcg_values = []
hr_seren_values = []
ndcg_seren_values = []

hr_cold_user = []
ndcg_cold_user = []
hr_seren_cold_user = []
ndcg_seren_cold_user = []

rating_threshold = 3
serendipity_items = 0
serendipity_survival_items = 0
all_item_ids = set(all_item_ids)
number_negative_examples = 20
for k in [5,10]:
    for user_id in test_data['user_id'].unique():
        user_test_items = test_data[test_data['user_id'] == user_id]
        positive_items = user_test_items[user_test_items['rating'] > rating_threshold]['item_id'].tolist()
        if not positive_items:
            continue
        isColdUser = train_user_id_map.get(user_id) is None

        for target_item in positive_items:

            negative_items = user_test_items[user_test_items['rating'] <= rating_threshold]['item_id'].tolist()
            random.shuffle(negative_items)
            candidate_items = [target_item] + negative_items[:20]  # Limitar a 99 negativos
            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                 serendipity_items += 1
            if not len(candidate_items) >  number_negative_examples:
                interacted_items = set(data[data['user_id'] == user_id]['item_id'])
                non_interacted_items = all_item_ids - interacted_items
                filtered_items = data[data['item_id'].isin(non_interacted_items)]['item_id'].unique()
                num_items_to_select = number_negative_examples - len(candidate_items) + 1
                random_items = random.sample(list(filtered_items), num_items_to_select)
                candidate_items = candidate_items + random_items
            
            X_user = []
            items_id_list = []
            combined_embedding = []
            for item_id in candidate_items:
                user_idx = train_user_id_map.get(user_id)
                item_idx = train_item_id_map.get(item_id)
                user_embedding = user_embeddings[user_idx] if user_idx is not None else default_user_embedding
                item_embedding = item_embeddings_mf[item_idx] if item_idx is not None else default_item_embedding_svd
                item_embedding_bert = item_embeddings_dict[item_id]
                item_final = np.hstack((item_embedding_bert, item_embedding))
                
                #calculate serendipity using the serendipity classifier
                serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
                serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
                
                # favour serenpity interactions
                serendipity_weight = 1 + serendipit_pred
                item_final = item_final * serendipity_weight
            
                # add serendipity as a feature
                serendipity_feature = np.array([serendipit_pred]).reshape(1, -1).flatten()
                
                combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
                X_user.append(combined_embedding)
                items_id_list.append(item_id)
        
            X_user = np.array(X_user)
            y_score = xgb_model.predict(X_user)
        
            predicted_ratings = pd.DataFrame({
                'item_id': candidate_items,
                'predicted_rating': y_score
            })
        
            predicted_ratings = predicted_ratings.sort_values(by='predicted_rating', ascending=False)
            ordered_items = predicted_ratings['item_id'].tolist()
            hr = hit_rate_at_k(ordered_items, [target_item], k)
            ndcg = ndcg_at_k(ordered_items, [target_item], k)
            hr_values.append(hr)
            ndcg_values.append(ndcg)

            if isColdUser:
                hr_cold_user.append(hr)
                ndcg_cold_user.append(ndcg)

            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                hr_seren_values.append(hr)
                ndcg_seren_values.append(ndcg)

                if isColdUser:
                    hr_seren_cold_user.append(hr)
                    ndcg_seren_cold_user.append(ndcg)

        
    average_hr = np.mean(hr_values)
    average_ndcg = np.mean(ndcg_values)
    average_hr_seren = np.mean(hr_seren_values)
    average_ndcg_seren = np.mean(ndcg_seren_values)
    average_hr_cold_user = np.mean(hr_cold_user)
    average_ndcg_cold_user = np.mean(ndcg_cold_user)
    average_hr_seren_cold_user = np.mean(hr_seren_cold_user)
    average_ndcg_seren_cold_user = np.mean(ndcg_seren_cold_user)
    
    print(f"Average HR@{k}: {average_hr}")
    print(f"Average NDCG@{k}: {average_ndcg}")
    print(f"Average HR_seren@{k}: {average_hr_seren}")
    print(f"Average NDCG_seren@{k}: {average_ndcg_seren}")
    print(f"Average HR_cold_user@{k}: {average_hr_cold_user}")
    print(f"Average NDCG_cold_user@{k}: {average_ndcg_cold_user}")
    print(f"Average HR_seren_cold_user@{k}: {average_hr_seren_cold_user}")
    print(f"Average NDCG_seren_cold_user@{k}: {average_ndcg_seren_cold_user}")
# Out:
# Average HR@5: 0.25431472081218276
# Average NDCG@5: 0.14964873018582983
# Average HR_seren@5: 0.3804347826086957
# Average NDCG_seren@5: 0.22120992538021717
# Average HR_cold_user@5: 0.125
# Average NDCG_cold_user@5: 0.0706831095982161
# Average HR_seren_cold_user@5: 0.1
# Average NDCG_seren_cold_user@5: 0.05
# Average HR@10: 0.3769035532994924
# Average NDCG@10: 0.18908252040131046
# Average HR_seren@10: 0.43478260869565216
# Average NDCG_seren@10: 0.24156002068892166
# Average HR_cold_user@10: 0.21875
# Average NDCG_cold_user@10: 0.09906026408154103
# Average HR_seren_cold_user@10: 0.15
# Average NDCG_seren_cold_user@10: 0.059394140144926146
