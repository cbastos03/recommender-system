# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from sklearn.metrics import precision_score, recall_score, accuracy_score, mean_squared_error, mean_absolute_error
import optuna
import xgboost as xgb
import numpy as np

train_data = pd.read_csv('../train_data.csv', dtype={'item_id': str}, sep=';')
test_data = pd.read_csv('../test_data.csv', dtype={'item_id': str}, sep=';')
data = pd.read_csv('../Data/serenlens_with_features_cleaned_filtered.csv', dtype={'item_id': str}, sep=";")
all_item_ids = data['item_id'].unique()

# load serendipity classifier model
predict_serendipity = xgb.XGBClassifier()
predict_serendipity.load_model('../serendipity_classifier/serendipity_classifier_mpmet.json')

def load_embeddings(embedding_path, item_ids):
    embeddings = np.load(embedding_path)
    return {item_id: normalize(embedding.reshape(1, -1)).flatten() for item_id, embedding in zip(item_ids, embeddings)}

train_user_ids = train_data['user_id'].unique()
train_item_ids = train_data['item_id'].unique()
train_user_id_map = {user_id: idx for idx, user_id in enumerate(train_user_ids)}
train_item_id_map = {item_id: idx for idx, item_id in enumerate(train_item_ids)}

interaction_matrix = train_data.pivot(index='user_id', columns='item_id', values='rating').fillna(0)
svd = TruncatedSVD(n_components=50, random_state=42)
user_embeddings = svd.fit_transform(interaction_matrix)
item_embeddings_mf = svd.components_.T

scaler = StandardScaler()
user_embeddings = scaler.fit_transform(user_embeddings)
item_embeddings_mf = scaler.fit_transform(item_embeddings_mf)

# description embeddings
item_embeddings_dict = load_embeddings('../embeddings/all_mpnet_base_embeddings.npy', all_item_ids)

# default embedding for missing embeddings in test
default_user_embedding = np.mean(user_embeddings, axis=0)
default_item_embedding_svd = np.mean(item_embeddings_mf, axis=0)

default_user_embedding = normalize(default_user_embedding.reshape(1, -1)).flatten()
default_item_embedding_svd = normalize(default_item_embedding_svd.reshape(1, -1)).flatten()

train_data_samples = []

for idx, row in train_data.iterrows():
    user_idx = train_user_id_map.get(row['user_id'])
    item_idx = train_item_id_map.get(row['item_id'])
    user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
    item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
    item_embedding_bert = item_embeddings_dict[row['item_id']]
    item_final = np.hstack((item_embedding_bert, item_embedding))

    #calculate serendipity using the serendipity classifier
    serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
    serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
    
    # favour serenpity interactions
    serendipity_weight = 1 + serendipit_pred  # Atribua mais peso se o item for serendipitoso
    item_final = item_final * serendipity_weight

    # add serendipity as a feature
    serendipity_feature = np.array([serendipit_pred]).reshape(1, -1).flatten()
    
    combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
    train_data_samples.append((combined_embedding, row['rating']))


X_train, y_train = zip(*train_data_samples)
X_train = np.array(X_train)
y_train = np.array(y_train)

test_data_samples = []
for idx, row in test_data.iterrows():
    user_idx = train_user_id_map.get(row['user_id'])
    item_idx = train_item_id_map.get(row['item_id'])
    user_embedding = normalize(user_embeddings[user_idx].reshape(1, -1)).flatten() if user_idx is not None else default_user_embedding
    item_embedding = normalize(item_embeddings_mf[item_idx].reshape(1, -1)).flatten() if item_idx is not None else default_item_embedding_svd
    item_embedding_bert = item_embeddings_dict[row['item_id']]
    item_final = np.hstack((item_embedding_bert, item_embedding))

    #calculate serendipity using the serendipity classifier
    #consider in tests as if the real-world example would calculate it in order to integrate new interactions in the system
    serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
    serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
    
    serendipity_weight = 1 + serendipit_pred  # Atribua mais peso se o item for serendipitoso
    item_final = item_final * serendipity_weight

    # add serendipity as a feature
    serendipity_feature = np.array([serendipit_pred]).reshape(1, -1).flatten()
    
    combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
    test_data_samples.append((combined_embedding, row['rating']))

X_test, y_test = zip(*test_data_samples)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

def objective(trial):
    param = {
        'objective': 'reg:squarederror',
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
    }
    
    xgb_model = xgb.XGBRegressor(**param)
    
    X_train_opt, X_valid_opt, y_train_opt, y_valid_opt = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    
    xgb_model.fit(X_train_opt, y_train_opt, eval_set=[(X_valid_opt, y_valid_opt)], verbose=False)
    
    y_pred = xgb_model.predict(X_valid_opt)
    
    mse = mean_squared_error(y_valid_opt, y_pred)
    
    # minimize mse    
    return mse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print("best hyperparameters found:")
print(study.best_params)

# use best hyperparameters
best_params = study.best_params
xgb_model = xgb.XGBRegressor(**best_params)
xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=True)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'test MSE: {mse}')
print(f'test MAE: {mae}')
# Out:
# [I 2024-09-21 18:08:58,771] A new study created in memory with name: no-name-f6b6f6a4-84df-45e6-ad6f-529ba2012981
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:118: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:119: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:120: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:122: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 18:09:09,255] Trial 0 finished with value: 0.7792341113090515 and parameters: {'n_estimators': 248, 'max_depth': 6, 'learning_rate': 0.014158853328294132, 'subsample': 0.6747748605384402, 'colsample_bytree': 0.9274371306934359, 'reg_alpha': 1.3102180442428724, 'reg_lambda': 0.12707453211225508}. Best is trial 0 with value: 0.7792341113090515.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:118: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:119: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:120: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:122: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 18:09:42,421] Trial 1 finished with value: 0.770498514175415 and parameters: {'n_estimators': 358, 'max_depth': 8, 'learning_rate': 0.01979763708190181, 'subsample': 0.9521692309151618, 'colsample_bytree': 0.6479658436932995, 'reg_alpha': 1.8039181921412093, 'reg_lambda': 0.12326189147401427}. Best is trial 1 with value: 0.770498514175415.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:118: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:119: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:120: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:122: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 18:10:06,182] Trial 2 finished with value: 0.7939808964729309 and parameters: {'n_estimators': 395, 'max_depth': 7, 'learning_rate': 0.08025955184955431, 'subsample': 0.9810951982894902, 'colsample_bytree': 0.6883412996070475, 'reg_alpha': 5.118519881490561, 'reg_lambda': 9.946924591126844}. Best is trial 1 with value: 0.770498514175415.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:118: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:119: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:120: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:122: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 18:10:26,579] Trial 3 finished with value: 0.8098534941673279 and parameters: {'n_estimators': 438, 'max_depth': 6, 'learning_rate': 0.08516978477815285, 'subsample': 0.6428236459700847, 'colsample_bytree': 0.9850089919648156, 'reg_alpha': 3.003159708271472, 'reg_lambda': 2.1210305686353474}. Best is trial 1 with value: 0.770498514175415.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:118: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:119: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:120: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:122: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 18:10:34,110] Trial 4 finished with value: 0.7834893465042114 and parameters: {'n_estimators': 496, 'max_depth': 3, 'learning_rate': 0.018822956805570105, 'subsample': 0.8837151606194493, 'colsample_bytree': 0.9018388907192454, 'reg_alpha': 2.1040751190693165, 'reg_lambda': 0.793311346744604}. Best is trial 1 with value: 0.770498514175415.
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:118: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:119: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:120: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:121: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 0.1, 10),
# C:\Users\alunoDEI\AppData\Local\Temp\ipykernel_8476\1990961423.py:122: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda', 0.1, 10),
# [I 2024-09-21 18
# {'n_estimators': 443, 'max_depth': 10, 'learning_rate': 0.011868465809620948, 'subsample': 0.9999281274909111, 'colsample_bytree': 0.6049965449997096, 'reg_alpha': 6.901656098427299, 'reg_lambda': 0.12475897407071213}
# [0]	validation_0-rmse:0.94682
# [1]	validation_0-rmse:0.94598
# [2]	validation_0-rmse:0.94499
# [3]	validation_0-rmse:0.94385
# [4]	validation_0-rmse:0.94295
# [5]	validation_0-rmse:0.94200
# [6]	validation_0-rmse:0.94099
# [7]	validation_0-rmse:0.94011
# [8]	validation_0-rmse:0.93918
# [9]	validation_0-rmse:0.93841
# [10]	validation_0-rmse:0.93745
# [11]	validation_0-rmse:0.93643
# [12]	validation_0-rmse:0.93562
# [13]	validation_0-rmse:0.93498
# [14]	validation_0-rmse:0.93422
# [15]	validation_0-rmse:0.93353
# [16]	validation_0-rmse:0.93285
# [17]	validation_0-rmse:0.93200
# [18]	validation_0-rmse:0.93127
# [19]	validation_0-rmse:0.93054
# [20]	validation_0-rmse:0.92962
# [21]	validation_0-rmse:0.92897
# [22]	validation_0-rmse:0.92842
# [23]	validation_0-rmse:0.92770
# [24]	validation_0-rmse:0.92702
# [25]	validation_0-rmse:0.92658
# [26]	validation_0-rmse:0.92600
# [27]	validation_0-rmse:0.92530
# [28]	validation_0-rmse:0.92479
# [29]	validation_0-rmse:0.92439
# [30]	validation_0-rmse:0.92392
# [31]	validation_0-rmse:0.92351
# [32]	validation_0-rmse:0.92306
# [33]	validation_0-rmse:0.92253
# [34]	validation_0-rmse:0.92217
# [35]	validation_0-rmse:0.92159
# [36]	validation_0-rmse:0.92122
# [37]	validation_0-rmse:0.92084
# [38]	validation_0-rmse:0.92042
# [39]	validation_0-rmse:0.92007
# [40]	validation_0-rmse:0.91955
# [41]	validation_0-rmse:0.91917
# [42]	validation_0-rmse:0.91870
# [43]	validation_0-rmse:0.91841
# [44]	validation_0-rmse:0.91799
# [45]	validation_0-rmse:0.91779
# [46]	validation_0-rmse:0.91744
# [47]	validation_0-rmse:0.91701
# [48]	validation_0-rmse:0.91659
# [49]	validation_0-rmse:0.91623
# [50]	validation_0-rmse:0.91580
# [51]	validation_0-rmse:0.91537
# [52]	validation_0-rmse:0.91506
# [53]	validation_0-rmse:0.91476
# [54]	validation_0-rmse:0.91450
# [55]	validation_0-rmse:0.91419
# [56]	validation_0-rmse:0.91389
# [57]	validation_0-rmse:0.91376
# [58]	validation_0-rmse:0.91349
# [59]	validation_0-rmse:0.91325
# [60]	validation_0-rmse:0.91291
# [61]	validation_0-rmse:0.91259
# [62]	validation_0-rmse:0.91233
# [63]	validation_0-rmse:0.91221
# [64]	validation_0-rmse:0.91202
# [65]	validation_0-rmse:0.91162
# [66]	validation_0-rmse:0.91122
# [67]	validation_0-rmse:0.91099
# [68]	validation_0-rmse:0.91078
# [69]	validation_0-rmse:0.91051
# [70]	validation_0-rmse:0.91015
# [71]	validation_0-rmse:0.90989
# [72]	validation_0-rmse:0.90957
# [73]	validation_0-rmse:0.90937
# [74]	validation_0-rmse:0.90922
# [313]	validation_0-rmse:0.89536
# [314]	validation_0-rmse:0.89536
# [315]	validation_0-rmse:0.89545
# [316]	validation_0-rmse:0.89547
# [317]	validation_0-rmse:0.89543
# [318]	validation_0-rmse:0.89543
# [319]	validation_0-rmse:0.89542
# [320]	validation_0-rmse:0.89546
# [321]	validation_0-rmse:0.89556
# [322]	validation_0-rmse:0.89561
# [323]	validation_0-rmse:0.89560
# [324]	validation_0-rmse:0.89565
# [325]	validation_0-rmse:0.89564
# [326]	validation_0-rmse:0.89569
# [327]	validation_0-rmse:0.89568
# [328]	validation_0-rmse:0.89570
# [329]	validation_0-rmse:0.89571
# [330]	validation_0-rmse:0.89570
# [331]	validation_0-rmse:0.89575
# [332]	validation_0-rmse:0.89573
# [333]	validation_0-rmse:0.89576
# [334]	validation_0-rmse:0.89581
# [335]	validation_0-rmse:0.89585
# [336]	validation_0-rmse:0.89585
# [337]	validation_0-rmse:0.89585
# [338]	validation_0-rmse:0.89585
# [339]	validation_0-rmse:0.89587
# [340]	validation_0-rmse:0.89588
# [341]	validation_0-rmse:0.89590
# [342]	validation_0-rmse:0.89585
# [343]	validation_0-rmse:0.89586
# [344]	validation_0-rmse:0.89584
# [345]	validation_0-rmse:0.89588
# [346]	validation_0-rmse:0.89593
# [347]	validation_0-rmse:0.89591
# [348]	validation_0-rmse:0.89597
# [349]	validation_0-rmse:0.89590
# [350]	validation_0-rmse:0.89591
# [351]	validation_0-rmse:0.89593
# [352]	validation_0-rmse:0.89595
# [353]	validation_0-rmse:0.89589
# [354]	validation_0-rmse:0.89593
# [355]	validation_0-rmse:0.89593
# [356]	validation_0-rmse:0.89593
# [357]	validation_0-rmse:0.89591
# [358]	validation_0-rmse:0.89590
# [359]	validation_0-rmse:0.89593
# [360]	validation_0-rmse:0.89592
# [361]	validation_0-rmse:0.89595
# [362]	validation_0-rmse:0.89594
# [363]	validation_0-rmse:0.89600
# [364]	validation_0-rmse:0.89597
# [365]	validation_0-rmse:0.89599
# [366]	validation_0-rmse:0.89601
# [367]	validation_0-rmse:0.89596
# [368]	validation_0-rmse:0.89606
# [369]	validation_0-rmse:0.89611
# [370]	validation_0-rmse:0.89613
# [371]	validation_0-rmse:0.89618
# [372]	validation_0-rmse:0.89620
# [373]	validation_0-rmse:0.89621
# [374]	validation_0-rmse:0.89622
# [375]	validation_0-rmse:0.89624
# [376]	validation_0-rmse:0.89622
# [377]	validation_0-rmse:0.89627
# [378]	validation_0-rmse:0.89631
# [379]	validation_0-rmse:0.89638
# [380]	validation_0-rmse:0.89639
# [381]	validation_0-rmse:0.89640
# [382]	validation_0-rmse:0.89641
# [383]	validation_0-rmse:0.89644
# [384]	validation_0-rmse:0.89646
# [385]	validation_0-rmse:0.89648
# [386]	validation_0-rmse:0.89648
# [387]	validation_0-rmse:0.89648
# [388]	validation_0-rmse:0.89653
# [389]	validation_0-rmse:0.89653
# [390]	validation_0-rmse:0.89656
# [391]	validation_0-rmse:0.89656
# [392]	validation_0-rmse:0.89657
# [393]	validation_0-rmse:0.89657
# [394]	validation_0-rmse:0.89651
# [395]	validation_0-rmse:0.89651
# [396]	validation_0-rmse:0.89657
# [397]	validation_0-rmse:0.89657
# [398]	validation_0-rmse:0.89658
# [399]	validation_0-rmse:0.89658
# [400]	validation_0-rmse:0.89659
# [401]	validation_0-rmse:0.89658
# [402]	validation_0-rmse:0.89659
# [403]	validation_0-rmse:0.89662
# [404]	validation_0-rmse:0.89670
# [405]	validation_0-rmse:0.89673
# [406]	validation_0-rmse:0.89675
# [407]	validation_0-rmse:0.89675
# [408]	validation_0-rmse:0.89671
# [409]	validation_0-rmse:0.89673
# [410]	validation_0-rmse:0.89676
# [411]	validation_0-rmse:0.89679
# [412]	validation_0-rmse:0.89676
# [413]	validation_0-rmse:0.89683
# [414]	validation_0-rmse:0.89684
# [415]	validation_0-rmse:0.89689
# [416]	validation_0-rmse:0.89693
# [417]	validation_0-rmse:0.89694
# [418]	validation_0-rmse:0.89697
# [419]	validation_0-rmse:0.89697
# [420]	validation_0-rmse:0.89701
# [421]	validation_0-rmse:0.89704
# [422]	validation_0-rmse:0.89710
# [423]	validation_0-rmse:0.89716
# [424]	validation_0-rmse:0.89719
# [425]	validation_0-rmse:0.89724
# [426]	validation_0-rmse:0.89724
# [427]	validation_0-rmse:0.89728
# [428]	validation_0-rmse:0.89735
# [429]	validation_0-rmse:0.89737
# [430]	validation_0-rmse:0.89739
# [431]	validation_0-rmse:0.89747
# [432]	validation_0-rmse:0.89746
# [433]	validation_0-rmse:0.89745
# [434]	validation_0-rmse:0.89746
# [435]	validation_0-rmse:0.89747
# [436]	validation_0-rmse:0.89750
# [437]	validation_0-rmse:0.89750
# [438]	validation_0-rmse:0.89751
# [439]	validation_0-rmse:0.89755
# [440]	validation_0-rmse:0.89752
# [441]	validation_0-rmse:0.89755
# [442]	validation_0-rmse:0.89757
# test MSE: 0.8056400418281555
# test MAE: 0.6912496089935303

# %%
import numpy as np
import random

def hit_rate_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    hits = len(set(predicted_at_k) & set(true_items))
    return 1.0 if hits > 0 else 0.0

def ndcg_at_k(predicted_items, true_items, k):
    predicted_at_k = predicted_items[:k]
    dcg = 0.0
    idcg = sum((1.0 / np.log2(i + 2) for i in range(min(len(true_items), k))))
    
    for i, item in enumerate(predicted_at_k):
        if item in true_items:
            dcg += 1.0 / np.log2(i + 2)

    return dcg / idcg if idcg > 0 else 0.0

hr_values = []
ndcg_values = []
hr_seren_values = []
ndcg_seren_values = []
rating_threshold = 3
serendipity_items = 0
serendipity_survival_items = 0
all_item_ids = set(all_item_ids)
number_negative_examples = 20
for k in [5,10]:
    for user_id in test_data['user_id'].unique():
        user_test_items = test_data[test_data['user_id'] == user_id]
        positive_items = user_test_items[user_test_items['rating'] > rating_threshold]['item_id'].tolist()
        if not positive_items:
            continue


        for target_item in positive_items:

            negative_items = user_test_items[user_test_items['rating'] <= rating_threshold]['item_id'].tolist()
            random.shuffle(negative_items)
            candidate_items = [target_item] + negative_items[:20]  # Limitar a 99 negativos
            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                 serendipity_items += 1
            if not len(candidate_items) >  number_negative_examples:
                interacted_items = set(data[data['user_id'] == user_id]['item_id'])
                non_interacted_items = all_item_ids - interacted_items
                filtered_items = data[data['item_id'].isin(non_interacted_items)]['item_id'].unique()
                num_items_to_select = number_negative_examples - len(candidate_items) + 1
                random_items = random.sample(list(filtered_items), num_items_to_select)
                candidate_items = candidate_items + random_items
            
            X_user = []
            items_id_list = []
            for item_id in candidate_items:
                user_idx = train_user_id_map.get(user_id)
                item_idx = train_item_id_map.get(item_id)
                user_embedding = user_embeddings[user_idx]if user_idx is not None else default_user_embedding
                item_embedding = item_embeddings_mf[item_idx] if item_idx is not None else default_item_embedding_svd
                item_embedding_bert = item_embeddings_dict[item_id]
                item_final = np.hstack((item_embedding_bert, item_embedding))
                
                #calculate serendipity using the serendipity classifier
                #consider in tests as if the real-world example would calculate it in order to integrate new interactions in the system
                serendipity_input = np.array(np.hstack((user_embedding, item_final))).reshape(1, -1)
                serendipit_pred = predict_serendipity.predict_proba(serendipity_input)[:, 1]
                serendipity_weight = 1 + serendipit_pred  # Atribua mais peso se o item for serendipitoso
                item_final = item_final * serendipity_weight
            
                # add serendipity as a feature
                serendipity_feature = np.array([serendipit_pred]).reshape(1, -1).flatten()
                
                combined_embedding = np.hstack((user_embedding, item_final, serendipity_feature))
                X_user.append(combined_embedding)
                items_id_list.append(item_id)
        
            X_user = np.array(X_user)
            y_score = xgb_model.predict(X_user)
        
            predicted_ratings = pd.DataFrame({
                'item_id': candidate_items,
                'predicted_rating': y_score
            })
        
            predicted_ratings = predicted_ratings.sort_values(by='predicted_rating', ascending=False)
            ordered_items = predicted_ratings['item_id'].tolist()
            hr = hit_rate_at_k(ordered_items, [target_item], k)
            ndcg = ndcg_at_k(ordered_items, [target_item], k)
            hr_values.append(hr)
            ndcg_values.append(ndcg)

            serendipity_value = data[(data['user_id'] == user_id) & (data['item_id'] == target_item)]['serendipity'].values[0]
            if serendipity_value == 1:
                serendipity_survival_items += 1
                hr = hit_rate_at_k(ordered_items, [target_item], k)
                ndcg = ndcg_at_k(ordered_items, [target_item], k)
                hr_seren_values.append(hr)
                ndcg_seren_values.append(ndcg)

        
    average_hr = np.mean(hr_values)
    average_ndcg = np.mean(ndcg_values)
    average_hr_seren = np.mean(hr_seren_values)
    average_ndcg_seren = np.mean(ndcg_seren_values)
    
    print(f"Average HR@{k}: {average_hr}")
    print(f"Average NDCG@{k}: {average_ndcg}")
    print(f"Average HR_seren@{k}: {average_hr_seren}")
    print(f"Average NDCG_seren@{k}: {average_ndcg_seren}")
# Out:
# Average HR@5: 0.22842639593908629
# Average NDCG@5: 0.13810195401832392
# Average HR_seren@5: 0.2717391304347826
# Average NDCG_seren@5: 0.18858159058350638
# Average HR@10: 0.350253807106599
# Average NDCG@10: 0.1767580413088887
# Average HR_seren@10: 0.3695652173913043
# Average NDCG_seren@10: 0.20885330645391065
